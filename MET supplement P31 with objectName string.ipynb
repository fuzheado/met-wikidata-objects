# %%
# Supplement Wikidata items about Met's objects

# Script to supplement P31 statements for Met objects in Wikidata
# Start with getting all P31 statements
# Lookup the objectName in the Met database

# SPARQL query to list Met items without the P1932 set:
# https://w.wiki/6NiH

# Consider adding references
# Example: https://www.wikidata.org/wiki/Q18177495
# retrieved - 14 May 2015
# reference URL - http://www.metmuseum.org/collection/the-collection-online/search/435976

# Written to run on JupyterLab via https://paws.wmcloud.org

import pywikibot
import pandas as pd
from pywikibot import pagegenerators as pg
from pywikibot.data.sparql import SparqlQuery
import logging

from types import SimpleNamespace

import requests
import re
import numpy as np

from joblib import Parallel, delayed

from time import perf_counter
from tqdm.notebook import tqdm

def stringify_pywikibot_target(intarget) -> str:
    '''
    Take pywikibot target object and return a string version, or QID, or printed date object
    '''
    returnstring = ''
    # print ('Type', type(intarget))
    if isinstance(intarget, str):
        return intarget
    elif isinstance(intarget, pywikibot.page._wikibase.ItemPage):
        return intarget.id
    elif isinstance(intarget, pywikibot.WbTime):
        return str(intarget)
    return None

def retrieve_claim_propqual(item, inclaimprop, inclaimtarget=None, inqualprop=None, inqualvalue=None) -> list:
    ''' Retrieve an entire Wikidata claim if property/qualifier match 
        Only works with returning strings or items, which get returned as QIDs
    '''
    returnlist = []

    item.get(force=True)
    if not item.claims.get(inclaimprop):
        return returnlist
    for statement in item.claims[inclaimprop]:
        if not inclaimtarget:
            returnlist += [stringify_pywikibot_target(statement.target)]
        elif statement.target.id == inclaimtarget:
            # Process qualifiers, if they exist
            if inqualprop and inqualprop in statement.qualifiers:
                for qual in statement.qualifiers[inqualprop]: #iterate over all P1932
                    returnqualstring = stringify_pywikibot_target(qual.target)
                    if inqualvalue:
                        if inqualvalue == returnqualstring:
                            returnlist.append(returnqualstring)
                    else:
                        returnlist.append(returnqualstring)
            elif not inqualprop:
                # inclaimprop-inclaimtarget triple matched, but no qualifier specified
                # Then just return the inclaimtarget QID
                returnlist.append(stringify_pywikibot_target(statement.target))
    return returnlist

def metid_to_objectName (in_df, metid:str) -> str:
    '''Lookup met id (integer) in Dataframe loaded from Met CSV'''
    result = None
    foundrow = in_df.loc[in_df['Object ID'] == int(metid)]
    if not foundrow.empty:
        result = foundrow.at[foundrow.index[0],'Object Name']
    return result

def handle_item (item:pywikibot.page.ItemPage):
    # global counter
    
    object_name = None
    matched_qids = None

    counter.total += 1

    # tqdm.write(f"{item.id}")

    # Grab Met ID, which should return exactly one value
    metidlist    = retrieve_claim_propqual(item, 'P3634')
    instancelist = retrieve_claim_propqual(item, 'P31')
    if len(metidlist) != 1:
        tqdm.write(f"  {item.id}: Error, Met ID should be exactly one. Instead: {metidlist}")
        return

    metid = metidlist[0]  # Extract the lone Met ID

    # Look up object name, make sure to strip whitespace!
    object_name = metid_to_objectName (metdf, metid)
    if not object_name:
        tqdm.write(f"  {item.id}: Error, object name lookup with Met database returned empty")
        return
    try:
        object_name = object_name.strip()
    except AttributeError:
        tqdm.write(f"{item.id}: AttributeError for object_name: {object_name}")
        return

    # Grab Wikidata P31 claims
    item.claims.get('P31')
    for statement in item.claims.get('P31'):  # Get instance of

        if 'P1932' in statement.qualifiers:
            for qual in statement.qualifiers['P1932']: #iterate over all
                tqdm.write(f"{item.id}: Error, found unexpected P31|{statement.target.id}|P1932 claims: {qual}")
                # object_name = stringify_pywikibot_target(qual.target)
            continue

        # Output status message
        pbar.set_postfix_str(f"{item.id}: {metid}, should be {object_name}")

        tqdm.write(f"Add {item.id}: {metid}, {statement.target.id}, '{object_name}'")

        # Add qualifier with objectName string from Met
        qualifier = pywikibot.Claim(repo, 'P1932')
        try:
            qualifier.setTarget(object_name)
        except ValueError:
            tqdm.write(f"  could not set object name to {object_name}")
            return
        statement.addQualifier(qualifier) # summary=u'Adding a qualifier.'

        counter.statements += 1

    counter.supplemented += 1
    return

if __name__ == '__main__':

    # Init counters
    counterdict = {
        'total': 0,
        'supplemented': 0,
        'statements': 0,
        'start_time': 0,
        'end_time': 0
    }
    counter = SimpleNamespace(**counterdict)

    # LOG = "met-supplement-p31.log"
    # logging.basicConfig(filename=LOG, filemode="w", level=logging.DEBUG)

    # LOAD Met CSV
    if metdf.empty:
        metdf = pd.read_csv('MetObjects.csv',low_memory=False)

    # Do SPARQL query to grab all entries of P31->Q18593264 and no qualifier
    # Return QID, Met ID
    QUERY = '''
    SELECT ?item ?thing ?metid WHERE {
      # ?item wdt:P3634 ?metid .
      MINUS { ?item p:P31 [ps:P31 ?thing; pq:P1932 [] ] }
      # ?item wdt:P31 ?thing .
    } 
    '''

    # For SPARQL generator
    wikidata_site = pywikibot.Site("wikidata", "wikidata")
    repo = wikidata_site.data_repository()
    generator = pg.WikidataSPARQLPageGenerator(QUERY, site=wikidata_site)

    pbar = tqdm(generator) # For progress bar
    counter.start_time = perf_counter()
    for item in pbar:
        handle_item(item)

    # Possible joblib speedup? Not happening
    # Parallel(n_jobs=8, prefer="threads")(delayed(handle_item)(i) for i in generator)
    counter.end_time = perf_counter()

    # Output final report
    tqdm.write(f"Finished")
    tqdm.write(f"Time elapsed: {counter.end_time-counter.start_time} secs")
    tqdm.write(f"Items examined: {counter.total}")
    tqdm.write(f"Items supplemented: {counter.supplemented}")
    tqdm.write(f"Statements added: {counter.statements}")
# Out:
# 0it [00:00, ?it/s]
#   Q20172025: Error, object name lookup with Met database returned empty
# Q97013416: AttributeError for object_name: nan
# Add Q96184317: 364154, Q11060274, 'Print'
# Add Q78619827: 670942, Q3305213, 'Hanging scroll'
# Add Q116244673: 451492, Q6916434, 'Mosque lamp'
# Add Q116410533: 468598, Q1264081, 'Censer'
# Add Q104413027: 359882, Q11060274, 'Print'
# Add Q116329992: 14495, Q191851, 'Vase'
# Add Q116410564: 469930, Q1066288, 'Statuette'
# Add Q96802968: 271932, Q125191, 'Photograph'
# Add Q19925198: 12703, Q3305213, 'Painting, miniature'
# Add Q116398959: 197569, Q245005, 'Teapot'
# Add Q116352455: 6069, Q57216, 'Plate'
# Add Q98821665: 787917, Q125191, 'Photograph'
# Add Q116371127: 2656, Q60310748, 'Cream pot'
# Add Q116313540: 49694, Q4364339, 'Plaque'
# Add Q116235479: 490684, Q132397, 'Pitcher'
# Add Q78683300: 75079, Q3305213, 'Folio'
# Add Q116445313: 823315, Q81727, 'Cup'
# Add Q104413108: 751510, Q2568536, 'Cradleboard'
# Add Q116273230: 454675, Q1348059, 'Panel'
# Add Q116364971: 6154, Q57216, 'Plate'
# Add Q116256776: 550552, Q2442735, 'Scarab'
# Add Q116392381: 6018, Q57216, 'Plate'
# Add Q116364886: 6163, Q57216, 'Plate'
# Add Q105809560: 45746, Q193220, 'Folding fan mounted as an album leaf'
# Add Q20173801: 14429, Q3305213, 'Painting, miniature'
# Add Q96183127: 291591, Q125191, 'Photogram'
# Add Q96357722: 491411, Q11060274, 'Print'
# Add Q116240678: 206412, Q10672725, 'Snuffbox'
# Add Q116370822: 2948, Q18349459, 'Cup plate'
# Add Q116409193: 434360, Q1190417, 'Baseball card, print'
# Add Q116351789: 7012, Q5771190, 'Salt'
# Add Q83560054: 2295, Q153988, 'Bowl'
# Add Q19912055: 437255, Q3305213, 'Painting'
# Add Q83561985: 19525, Q11285759, 'Armchair'
# Add Q116342581: 9412, Q191851, 'Vase'
# Add Q96586229: 708988, Q125191, 'Photograph'
# Add Q78747500: 54737, Q3305213, 'Album leaf'
# Add Q19912292: 436760, Q3305213, 'Painting'
# Add Q116306899: 210780, Q4364339, 'Plaque'
# Add Q19913347: 440375, Q3305213, 'Painting'
# Add Q116431851: 556294, Q2442735, 'Scarab'
# Add Q29384545: 327830, Q3305213, 'Painted panel'
# Add Q116402362: 247493, Q579418, 'Lekythos'
# Add Q116373179: 610, Q18696213, 'Flask'
# Add Q78913615: 37859, Q3305213, 'Folio'
# Add Q97012779: 291776, Q125191, 'Daguerreotype'
# Add Q116313731: 49398, Q987767, 'Wine container'
# Add Q116392809: 7638, Q57216, 'Soup dish'
# Add Q116392809: 7638, Q17379525, 'Soup dish'
# Add Q116431662: 556171, Q1123756, 'Cylinder seal'
# Add Q20194076: 486182, Q3305213, 'Painting'
# Add Q116393619: 19845, Q191851, 'Vase'
# Add Q78850038: 45188, Q3305213, 'Hanging scroll'
# Add Q96357612: 364497, Q11060274, 'Print'
# Add Q116370536: 3335, Q746549, 'Dish'
# Add Q116243506: 460734, Q18451251, 'Goblet'
# Add Q19906262: 437520, Q3305213, 'Painting'
# Add Q97853182: 788302, Q11060274, 'Print'
# Add Q20200346: 488533, Q3305213, 'Drawing'
# Add Q116374120: 192728, Q17489160, 'Bust'
# Add Q116430941: 555579, Q131557, 'Amulet, frog'
# Add Q19911768: 437844, Q3305213, 'Painting'
# Add Q116431977: 556391, Q2442735, 'Scarab'
# Add Q19913198: 435986, Q3305213, 'Painting'
# Add Q116242938: 460884, Q18451251, 'Goblet'
# Add Q20199801: 483681, Q3305213, 'Drawing'
# Add Q116242761: 446204, Q153988, 'Bowl'
# Add Q116437794: 561011, Q2442735, 'Scarab'
# Add Q116412971: 501225, Q7295963, 'Rattle'
# Add Q19920891: 486406, Q3305213, 'Painting'
# Add Q116245691: 460218, Q746549, 'Dish'
# Add Q20200688: 493544, Q3305213, 'Print'
# Add Q20193708: 483758, Q17126091, 'Textile sample'
# Add Q116371318: 2508, Q2356786, 'Sugar bowl'
# Add Q20185492: 460332, Q3305213, 'Frame'
# Add Q20188372: 460116, Q3305213, 'Drawing'
# Add Q19917533: 486008, Q3305213, 'Painting'
# Add Q20177099: 15251, Q3305213, 'Painting, miniature'
# Add Q104412971: 4470, Q1207302, 'Chocolate jar'
# Add Q116432212: 556579, Q80228, 'Bottle'
# Add Q19914390: 481657, Q3305213, 'Painting'
# Add Q68352163: 81142, Q1034198, 'Cape'
# Add Q116309865: 207320, Q11285759, 'Armchair'
# Add Q20200080: 483409, Q860861, 'Sculpture'
# Add Q97731204: 337324, Q11060274, 'Print'
# Add Q116361616: 6552, Q3391771, 'Platter'
# Add Q116291597: 245469, Q673338, 'Alabastron'
# Add Q116288996: 253817, Q1665351, 'Intaglio'
# Add Q97768184: 679176, Q11060274, 'Print'
# Add Q116374203: 72393, Q29527347, 'Figure'
# Add Q96054119: 812821, Q11060274, 'Print'
# Add Q116280457: 546989, Q2442735, 'Scarab'
# Add Q116282362: 324126, Q860861, 'Sculpture'
# Add Q20190087: 486585, Q3305213, 'Print'
# Add Q116444768: 719111, Q189299, 'Necklace'
# Add Q96800641: 269129, Q125191, 'Photograph'
# Add Q116439213: 562753, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q102304806: 387811, Q18219090, 'Print'
# Add Q116406659: 268823, Q125191, 'Photograph'
# Add Q116244266: 460567, Q153988, 'Bowl'
# Add Q116392970: 8865, Q2569925, 'Trivet'
# Add Q96756857: 654090, Q1064538, 'Quilt'
# WARNING: API error mwoauth-invalid-authorization: The authorization headers in your request are not valid: Nonce already used: 21654220307546377761677402127
# ERROR: Retrying failed OAuth authentication for wikidata:wikidata: The authorization headers in your request are not valid: Nonce already used: 21654220307546377761677402127
# Add Q78712102: 73299, Q3305213, 'Handscrolls'
# Add Q116281220: 461283, Q2537127, 'Plaquette'
# Add Q20200241: 482449, Q3305213, 'Drawing'
# Add Q19923564: 486720, Q3305213, 'Drawing'
# Add Q116434136: 559301, Q1422576, 'Model dish, Perneb'
# Add Q116289741: 248393, Q860861, 'Head of a woman'
# Add Q116295944: 248777, Q1066288, 'Statuette of an actor'
# Add Q116366608: 4671, Q193358, 'Ladle'
# Add Q116311602: 188779, Q1066288, 'Statuette'
# Add Q98821644: 716313, Q125191, 'Photograph'
# Add Q116390629: 1367, Q151771, 'Candlestick'
# Add Q97852593: 775514, Q11060274, 'Print'
# Add Q116242861: 452027, Q860861, 'Figural vessel'
# Add Q116246220: 591035, Q726826, 'Shabti, Henettawy C'
# Add Q20194803: 488695, Q3305213, 'Painting'
# Add Q20197879: 491747, Q22075301, 'Textile piece'
# Add Q20197879: 491747, Q29639251, 'Textile piece'
# Add Q116306994: 206455, Q57216, 'Plate'
# Add Q20183472: 459108, Q3305213, 'Painting'
# Add Q78827925: 49131, Q3305213, 'Album'
# Add Q78827925: 49131, Q1173065, 'Album'
# Add Q19924960: 18113, Q3305213, 'Painting'
# Add Q98821630: 668005, Q125191, 'Photograph'
# Add Q116248174: 544246, Q148449, 'Magic wand'
# Add Q116289954: 254902, Q1539580, 'Pelike'
# Add Q116306807: 208577, Q3775662, 'Inkstand'
# Add Q116291469: 253660, Q28512, 'Cameo'
# Add Q19912344: 436416, Q3305213, 'Painting'
# Add Q116432109: 556487, Q2442735, 'Scarab'
# Add Q116406081: 255661, Q673338, 'Alabastron'
# Add Q116438270: 561255, Q11086567, 'Jar Fragment, Siptah'
# Add Q97775782: 756628, Q11060274, 'Print'
# Add Q97853184: 788303, Q11060274, 'Print'
# Add Q99807189: 87044, Q249975, 'Robe à la Française'
# Add Q116434036: 559285, Q1422576, 'Model dish, Perneb'
# Q29388338: AttributeError for object_name: nan
# Add Q116275472: 481002, Q81727, 'Cup'
# Add Q116371500: 2359, Q746549, 'Dish'
# Add Q116289896: 242015, Q179700, 'Statue of a priest'
# Add Q98820631: 263577, Q125191, 'Photograph'
# Add Q96586273: 769225, Q125191, 'Photograph'
# Add Q116409274: 446110, Q11086567, 'Fragment'
# Add Q116410504: 466365, Q193893, 'Capital'
# Add Q19923965: 12985, Q3305213, 'Painting, miniature'
# Add Q116344614: 7934, Q2356786, 'Sugar bowl'
# Add Q116390622: 1361, Q151771, 'Candlestick'
# Add Q19925419: 13006, Q3305213, 'Painting'
# Add Q97012672: 286330, Q125191, 'Photograph'
# Add Q100348239: 156947, Q8251241, 'Bootees'
# Add Q116243718: 545565, Q1066288, 'Figurine, Hippopotamus'
# Add Q116297184: 244074, Q1066288, 'Statuette of a woman'
# Add Q116417762: 550479, Q11086567, 'Foundation Deposit Plaque, Calf's Head'
# Add Q116439166: 562712, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116246272: 591017, Q726826, 'Shabti, Henettawy C'
# Add Q20200650: 488170, Q3575260, 'Pendant'
# Add Q20178086: 12736, Q18761202, 'Watercolor'
# Add Q116240852: 75405, Q722604, 'Reliquary'
# Add Q97772141: 754095, Q11060274, 'Print'
# Add Q116391270: 2471, Q188075, 'Box'
# Add Q98821553: 294427, Q125191, 'Photograph'
# Add Q78870319: 39657, Q3305213, 'Handscroll'
# Add Q29385801: 544501, Q178401, 'Amphora, ibex, blue-painted ware'
# Add Q116370389: 3529, Q1348059, 'Panel'
# Add Q116251924: 471374, Q1348059, 'Panel'
# Add Q116433608: 558933, Q95975776, 'Coffin Inlay'
# Add Q116307285: 205010, Q95921197, 'Salver'
# Add Q78233568: 36932, Q11060274, 'Print'
# Add Q100706414: 108052, Q200539, 'Dress'
# Add Q116282676: 258494, Q746549, 'Dish'
# Add Q116373440: 383, Q833823, 'Beaker'
# Add Q83562080: 38174, Q179700, 'Statue'
# Add Q83562310: 42718, Q29527347, 'Figure'
# Add Q116280655: 452519, Q208440, 'Chess piece'
# Add Q109567907: 285906, Q125191, 'Photograph'
# Add Q97769700: 712355, Q11060274, 'Print'
# Add Q97852646: 786241, Q11060274, 'Print'
# Add Q116273710: 464194, Q4364339, 'Plaque'
# Add Q116242700: 445692, Q28823, 'Fragment'
# Add Q116242700: 445692, Q11086567, 'Fragment'
# Add Q98225267: 811007, Q2741056, 'Cabinet'
# Add Q116242654: 447365, Q80228, 'Bottle'
# Add Q20191730: 491601, Q210064, 'Lamps'
# Add Q116310500: 195949, Q833823, 'Beaker'
# Add Q116417271: 550404, Q2442735, 'Scarab'
# Add Q19920775: 484540, Q3305213, 'Drawing'
# Add Q20201852: 473889, Q3305213, 'Statuette'
# Add Q116243085: 556962, Q11086567, 'Tile fragment'
# Add Q116243085: 556962, Q468402, 'Tile fragment'
# Add Q116273319: 469000, Q168456, 'Earring'
# Add Q116256244: 470792, Q193893, 'Capital'
# Add Q116290125: 248337, Q860861, 'Head of a woman'
# Add Q116333013: 7779, Q81895, 'Spoon'
# Add Q78913843: 37857, Q3305213, 'Folio'
# Add Q20175539: 10337, Q3305213, 'Painting'
# Add Q97850000: 757251, Q11060274, 'Print'
# Add Q116373439: 381, Q833823, 'Beaker'
# Add Q116250548: 38269, Q245117, 'Relief fragment'
# Add Q96185300: 544637, Q3305213, 'Facsimile, Rekhmire (TT 100), leather work, sandals'
# Add Q116289212: 250070, Q833823, 'Beaker'
# Add Q116396610: 53560, Q1317634, 'Cauldron'
# Add Q97768175: 678297, Q11060274, 'Print'
# Add Q96585920: 488055, Q860861, 'Sculpture'
# Add Q19914308: 439385, Q3305213, 'Painting'
# Add Q116374545: 38582, Q178743, 'Stele'
# Add Q116432294: 556655, Q2366864, 'Pot'
# Add Q100706419: 108079, Q200539, 'Dress'
# Add Q116413942: 545421, Q131557, 'Amulet, Heart'
# Add Q19913109: 437581, Q3305213, 'Painting, drawing'
# Add Q20199259: 490764, Q11060274, 'Print'
# Add Q116392515: 6406, Q57216, 'Plate'
# Add Q78883071: 37892, Q3305213, 'Folio'
# Add Q116280983: 467493, Q151771, 'Candlestick'
# Add Q96053862: 418781, Q1190417, 'Photograph, baseball card'
# Add Q116398953: 197565, Q245005, 'Teapot'
# Add Q96586188: 708768, Q125191, 'Photograph'
# Add Q116295379: 247205, Q1350279, 'Pyxis with lid'
# Add Q116295379: 247205, Q2488579, 'Pyxis with lid'
# Add Q116296807: 244159, Q330946, 'Dagger blade'
# Q98821690: AttributeError for object_name: nan
# Add Q116306713: 234099, Q548275, 'Candelabra'
# Add Q116246230: 591032, Q726826, 'Shabti, Henettawy C'
# Add Q19922175: 488826, Q3305213, 'Painting'
# Add Q97769695: 712333, Q11060274, 'Print'
# Add Q20190038: 486755, Q3305213, 'Painting'
# Add Q78620454: 670930, Q3305213, 'Hanging scroll'
# Add Q20193809: 485022, Q3305213, 'Painting'
# Add Q116374282: 44893, Q179700, 'Statue'
# Add Q98821372: 282762, Q125191, 'Transparency'
# Add Q116310690: 194295, Q57216, 'Plate'
# Add Q19917739: 632922, Q3305213, 'Painting'
# Add Q116371970: 1759, Q63495428, 'Side Chair'
# Add Q61040922: 49936, Q18219090, 'Woodblock print'
# Add Q78824136: 49255, Q3305213, 'Folding fan'
# Add Q96183809: 336669, Q11060274, 'Print'
# Add Q116343796: 7951, Q2356786, 'Sugar Bowl'
# Add Q19917829: 484891, Q3305213, 'Painting'
# Add Q116442925: 575508, Q1053956, 'Bead'
# Add Q116314153: 42172, Q987767, 'Wine vessel'
# Add Q19914098: 436298, Q3305213, 'Painting, miniature'
# Add Q116290171: 246599, Q755706, 'Kantharos'
# Add Q116411469: 473301, Q4364339, 'Plaque'
# Add Q20175198: 11324, Q3305213, 'Painting'
# Add Q116240966: 23143, Q858236, 'Breastplate'
# Add Q116326590: 20601, Q2106696, 'Dressing table'
# Add Q116436334: 560144, Q2442735, 'Scaraboid'
# Add Q19911654: 440393, Q3305213, 'Painting'
# Add Q98821589: 299327, Q125191, 'Photograph'
# Add Q19912018: 437049, Q3305213, 'Painting'
# Add Q116310374: 204640, Q11285759, 'Armchair'
# Add Q116442770: 573714, Q2442735, 'Scaraboid'
# Add Q116242123: 252963, Q579418, 'Lekythos'
# Add Q96357702: 491318, Q11060274, 'Print'
# Add Q19913470: 438551, Q3305213, 'Painting'
# Add Q19912050: 437012, Q3305213, 'Painting, cassone panel'
# Add Q116298482: 665567, Q132397, 'Pitcher'
# Add Q20197746: 487929, Q3305213, 'Painting'
# Add Q116275234: 562064, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q19917796: 632952, Q3305213, 'Painting'
# Add Q116392919: 8792, Q613972, 'Tray'
# Add Q116372440: 1255, Q151771, 'Candlestick'
# Add Q116240829: 191329, Q860861, 'Group'
# Add Q116240829: 191329, Q16887380, 'Group'
# Add Q116433030: 558619, Q2442735, 'Scarab'
# Add Q116247819: 471886, Q1348059, 'Panel'
# Add Q78840963: 45721, Q3305213, 'Hanging scroll'
# Add Q116374480: 38949, Q29527347, 'Figure'
# Add Q20190867: 486007, Q3305213, 'Painting'
# Add Q116398412: 196467, Q1066288, 'Statuette'
# Add Q98224650: 19821, Q46847, 'Ring'
# Add Q116378818: 9418, Q191851, 'Vase'
#   Q116726442: Error, object name lookup with Met database returned empty
# Add Q19918903: 486894, Q3305213, 'Painting'
# Add Q20178209: 16891, Q18761202, 'Watercolor'
# Add Q20178209: 16891, Q21281546, 'Watercolor'
# Add Q98821539: 291976, Q125191, 'Photographs'
# Add Q20197984: 493904, Q3305213, 'Sculpture'
# Add Q20198486: 482173, Q15026, 'Side chair'
# Add Q19912871: 437848, Q3305213, 'Painting'
# Add Q116431822: 556274, Q2442735, 'Scarab'
# Add Q116434624: 559464, Q2442735, 'Scarab'
# Add Q19924007: 21473, Q3305213, 'Painting, miniature'
# Add Q98823247: 267677, Q125191, 'Photograph'
# Add Q116256116: 472189, Q208454, 'Abacus'
# Add Q116314112: 44754, Q153988, 'Bowl'
# Add Q116280122: 559619, Q2442735, 'Scarab'
# Add Q116272638: 550311, Q2442735, 'Scarab, Ramesses II'
# Add Q78697342: 75008, Q3305213, 'Folio'
# Add Q97853976: 811880, Q11060274, 'Print'
# Add Q19914244: 436866, Q3305213, 'Painting'
# Add Q116314271: 44610, Q79137673, 'Screen'
# Add Q116308116: 199852, Q131647, 'Medal'
# Add Q19922840: 486541, Q3305213, 'Drawing'
# Add Q20189457: 486011, Q3305213, 'Painting'
# Add Q83562738: 73150, Q29527347, 'Figure'
# Add Q19912969: 436645, Q3305213, 'Painting'
# Add Q99810114: 168950, Q22676, 'Shoes'
# Add Q29384248: 310552, Q1264081, 'Vessel'
# Add Q116441040: 568790, Q11086567, 'Vase fragment'
# Add Q20201523: 471115, Q3305213, 'Roundel'
# Add Q116313235: 52990, Q188075, 'Box'
# Add Q96586246: 710774, Q11060274, 'Print'
# Add Q97854179: 812000, Q11060274, 'Print'
# Add Q116418559: 550735, Q726826, 'Shabti'
# Add Q116439157: 562702, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116332467: 9942, Q18451251, 'Goblet'
# Add Q116406059: 255646, Q838312, 'Pin'
# Add Q20201712: 471871, Q3305213, 'Lancet heads'
# Add Q96149039: 544161, Q1066288, 'Figurine, Hippopotamus'
# Add Q98823330: 282514, Q125191, 'Photograph'
# Add Q116282336: 322349, Q41207, 'Coin'
# Add Q98823787: 291401, Q125191, 'Photograph'
# Add Q116236438: 467760, Q96097957, 'Coffret'
# Add Q116289574: 249399, Q81727, 'Cup'
# Add Q116343422: 7959, Q2356786, 'Sugar bowl'
# Add Q97580141: 283197, Q125191, 'Photograph'
# Add Q116328487: 16738, Q2990690, 'Compote'
# Add Q116402911: 251166, Q1066288, 'Statuette of a woman'
# Add Q116377488: 38181, Q29527347, 'Figure'
# Add Q116366226: 4786, Q14748, 'Library table'
# Add Q116297203: 246911, Q1138737, 'Lamp'
# Add Q116444842: 742380, Q189299, 'Necklace'
# Add Q78759717: 53405, Q3305213, 'Pair of hanging scrolls'
# Add Q19930492: 11145, Q3305213, 'Painting'
# Add Q78841516: 45711, Q3305213, 'Painting'
# Add Q116372843: 859, Q153988, 'Bowl'
# Add Q19913092: 438375, Q3305213, 'Painting'
# Add Q20188139: 460799, Q3305213, 'Leaf from a book of hours (?)'
# Add Q97579778: 268098, Q125191, 'Photograph'
# Add Q116272793: 455024, Q48498, 'Illustrated manuscript'
# Add Q19924747: 11107, Q3305213, 'Painting'
# Add Q116402475: 248796, Q579418, 'Lekythos'
# Add Q97012933: 291812, Q125191, 'Daguerreotype'
# Add Q19923822: 15013, Q3305213, 'Painting, miniature'
# Add Q20201637: 471073, Q3305213, 'Roundel'
# Add Q100706478: 168293, Q110304, 'Top hat'
# Add Q116245655: 460225, Q57216, 'Plate'
# Add Q116249865: 465236, Q499916, 'Brooch'
# Add Q116298430: 669093, Q1207302, 'Jar'
# Add Q116393690: 19918, Q191851, 'Vase'
# Add Q20200297: 484869, Q3305213, 'Drawing'
# Add Q97853036: 788027, Q11060274, 'Print'
# Add Q116274708: 548753, Q201097, 'Basket'
# Add Q116275207: 562062, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116274093: 464086, Q29382731, 'Garniture or mounting'
# Add Q116442033: 569629, Q2442735, 'Scarab'
# Add Q59769601: 55208, Q18219090, 'Print'
# Add Q19919352: 483199, Q3305213, 'Painting'
# Add Q116396220: 49353, Q29527347, 'Figure'
# Add Q116328504: 15862, Q191851, 'Vase'
# Add Q96035615: 403958, Q1190417, 'Baseball card, photograph'
# Add Q116310609: 199478, Q22075301, 'Length'
# Add Q116370435: 3458, Q6806674, 'Apothecary jar'
# Add Q78997019: 36035, Q3305213, 'Handscroll'
# Add Q96053874: 665862, Q1190417, 'Print baseball card'
# Add Q116371386: 2448, Q153988, 'Bowl'
# Add Q116444541: 700205, Q93184, 'Drawing'
# Add Q96586063: 491426, Q11060274, 'Print'
# Add Q116393292: 9955, Q1531435, 'Wine glass'
# Add Q116440178: 567880, Q4364339, 'Plaque'
# Add Q116399336: 199694, Q245005, 'Teapot'
# Add Q19912584: 437197, Q3305213, 'Painting'
# Add Q116252470: 471133, Q35473, 'Window'
# Add Q18708810: 240553, Q41971267, 'Krater, four-handled with lid'
# Add Q18708810: 240553, Q476968, 'Krater, four-handled with lid'
# Add Q116308195: 203090, Q29527347, 'Figure'
# Add Q19924842: 10774, Q3305213, 'Painting, miniature'
# Add Q116438735: 562272, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116289055: 246658, Q960844, 'Cinerary urn with lid'
# Add Q116289055: 246658, Q2488579, 'Cinerary urn with lid'
# Add Q20199616: 481950, Q3305213, 'Painting'
# Add Q96794921: 268312, Q125191, 'Photograph'
# Add Q116393714: 19942, Q191851, 'Vase'
# Add Q29385342: 463188, Q184296, 'Tapestry'
# Add Q116276267: 468219, Q29401129, 'Statue head'
# Add Q19917653: 484828, Q3305213, 'Painting'
# Add Q97731174: 294333, Q125191, 'Photograph'
# Add Q116409203: 444712, Q57216, 'Plate'
# Add Q97788452: 811266, Q11060274, 'Print'
# Add Q116314102: 44773, Q1317634, 'Cauldron'
# Add Q96035417: 403787, Q1190417, 'Baseball card, photograph'
# Add Q97581412: 302666, Q1757923, 'Carte-de-visite'
# Add Q19913381: 435957, Q3305213, 'Painting'
# Add Q116251857: 464548, Q115488, 'Medallion'
# Add Q100709858: 107687, Q200539, 'Dress'
# Add Q98821469: 289410, Q125191, 'Photograph'
# Add Q97013242: 702990, Q125191, 'Photograph'
#   Q99809843: Error, object name lookup with Met database returned empty
# Add Q116325504: 17503, Q1207302, 'Jar'
# Add Q116247640: 552414, Q2442735, 'Scarab'
# Add Q78835367: 48900, Q3305213, 'Hanging scroll'
# Add Q116445377: 825833, Q188075, 'Box'
# Add Q116235385: 545420, Q131557, 'Amulet, Heart'
# Add Q116309859: 206698, Q1066288, 'Statuette'
# Add Q116393108: 8965, Q2569925, 'Trivet'
# Add Q116430028: 555388, Q131557, 'Amulet'
# Add Q20201516: 471114, Q3305213, 'Roundel'
# Add Q20199355: 493415, Q3305213, 'Print'
# Add Q19914340: 490751, Q3305213, 'Painting'
# Add Q97732266: 389077, Q11060274, 'Print'
# Add Q116374349: 39851, Q245117, 'Relief'
# Add Q116308182: 202429, Q131647, 'Medal'
# Add Q116385786: 670002, Q468402, 'Tile'
# Add Q97013422: 821166, Q125191, 'Daguerreotype'
# Add Q116363858: 5612, Q57216, 'Plate'
# Add Q116441698: 569420, Q2442735, 'Scarab'
# Add Q116242716: 446236, Q2111434, 'Pendant'
# Add Q104413006: 20498, Q63495428, 'Side chair'
# Add Q20176921: 17515, Q3305213, 'Painting, miniature'
# Add Q116398254: 196321, Q468402, 'Tile'
# Add Q116335463: 7681, Q87718085, 'Soup plate'
# Add Q78761149: 53181, Q3305213, 'Hanging scroll'
# Add Q116394074: 21790, Q613972, 'Tray'
# Add Q116274137: 453574, Q35473, 'Window'
# Add Q116372311: 1390, Q151771, 'Candlestick'
# Add Q116393559: 18235, Q81895, 'Spoon'
# Add Q116240645: 209018, Q548275, 'Candelabra'
# Add Q116411369: 472765, Q65769142, 'Stamp'
# Add Q20200755: 489690, Q3305213, 'Drawing'
# Add Q97010008: 271912, Q125191, 'Photograph'
# Add Q116370236: 3707, Q18696213, 'Flask'
# Add Q100706556: 174738, Q535576, 'Bustle'
# Add Q29385050: 447086, Q1406758, 'Finial'
# Add Q116359219: 5812, Q60310748, 'Cream pot'
# Add Q19925713: 15987, Q3305213, 'Painting, miniature'
# Add Q19918589: 485842, Q3305213, 'Painting'
#   Q99809838: Error, object name lookup with Met database returned empty
# Add Q116246121: 460143, Q1888893, 'Albarello'
# Add Q96035708: 404336, Q1190417, 'Baseball card, photograph'
# Add Q116404666: 253659, Q2442735, 'Scaraboid'
# Add Q116311065: 232292, Q2148216, 'Upholstery panel'
# Add Q116341886: 8069, Q14748, 'Table'
# Add Q116280045: 477239, Q499916, 'Brooch'
# Add Q19921297: 488034, Q3305213, 'Painting'
# Add Q116444529: 698344, Q189299, 'Necklace'
# Add Q105693296: 825509, Q11060274, 'Print'
# Add Q116437626: 560982, Q1566584, 'Hair pin'
# Add Q78611922: 761570, Q3305213, 'Painting'
# Add Q116395494: 42219, Q746549, 'Dish'
# Add Q78875690: 38022, Q3305213, 'Painting'
# Add Q116274353: 487559, Q191851, 'Vase'
# Add Q29385655: 503670, Q281460, 'Pipe Organ'
# Add Q116314292: 47429, Q191851, 'Vase'
# Add Q19913650: 436345, Q3305213, 'Painting'
# Add Q97788823: 811536, Q11060274, 'Print'
# Add Q116276799: 467836, Q1348059, 'Panel'
# Add Q116287979: 255297, Q668349, 'Kylix'
# Add Q19924031: 17054, Q93184, 'Drawing'
# Add Q20201521: 471094, Q3305213, 'Roundel'
# Add Q78853099: 42343, Q3305213, 'Hanging scroll'
# Add Q116374455: 39016, Q1066288, 'Figurine'
# Add Q116332970: 8218, Q3446398, 'Tankard'
# Add Q116360485: 5777, Q132397, 'Pitcher'
# Add Q116289203: 248504, Q57216, 'Plate'
# Add Q116314328: 42059, Q581776, 'Boulder'
# Add Q19912338: 436456, Q3305213, 'Painting'
# Add Q98821034: 266453, Q57207952, 'Polaroid'
# Add Q116419569: 552736, Q191851, 'Vase'
# Add Q96278396: 55271, Q18219090, 'Print'
# Add Q97772136: 754011, Q11060274, 'Print'
# Add Q78706904: 74752, Q3305213, 'Painting'
# Add Q116289924: 246589, Q11086465, 'Neck-amphora'
# Add Q116351678: 7036, Q5771190, 'Salt'
# Add Q78617689: 671012, Q3305213, 'Hanging scroll'
# Add Q19925328: 12925, Q3305213, 'Painting'
# Add Q20187969: 458982, Q3305213, 'Painting'
# Add Q19924764: 17803, Q3305213, 'Painting'
# Add Q78839518: 45760, Q3305213, 'Hanging scroll'
# Add Q116370221: 3722, Q18696213, 'Flask'
# Add Q19911675: 437276, Q3305213, 'Painting'
# Add Q29383198: 24953, Q12791, 'Short sword (Yatagan)'
# Add Q116365619: 5432, Q821952, 'Whale oil lamp'
# Add Q96053445: 404518, Q1190417, 'Baseball card, photograph'
# Add Q98821656: 787904, Q125191, 'Photograph'
# Add Q116317047: 39623, Q238231, 'Disk'
# Add Q98225292: 840446, Q5078274, 'Sketch'
# Add Q68352246: 83259, Q2144456, 'Evening dress'
# Add Q68352246: 83259, Q1908472, 'Evening dress'
#   Q18338439: Error, Met ID should be exactly one. Instead: ['391070', '391069']
# Add Q116252527: 464897, Q499916, 'Brooch'
# Add Q116373167: 624, Q80228, 'Bottle'
# Add Q116438995: 562530, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116291785: 242604, Q168456, 'Earring'
# Add Q116289171: 249411, Q153988, 'Bowl'
# Add Q98821439: 285454, Q125191, 'Photograph'
# Add Q20198338: 482024, Q3305213, 'Painting'
# Add Q116275048: 562154, Q11086567, 'Relief fragment, tomb of Meketre'
#   Q19913265: Error, object name lookup with Met database returned empty
# Add Q78883012: 37893, Q3305213, 'Folio'
# Add Q116290118: 254881, Q11086465, 'Neck-amphora'
# Add Q100347845: 156329, Q876824, 'Wedding Slippers'
# Add Q98820745: 265169, Q125191, 'Photograph'
# Add Q116411586: 478984, Q46847, 'Ring'
# Add Q116291457: 245507, Q1066288, 'Statuette of a woman'
# Add Q116295806: 240718, Q2413314, 'Jug'
# Add Q19917459: 488768, Q3305213, 'Painting'
# Add Q116390141: 228, Q11285759, 'Armchair'
# Add Q83559882: 13148, Q17489160, 'Bust'
# Add Q116348666: 7862, Q81727, 'Cup'
# Add Q116389741: 666573, Q1264081, 'Incense burner'
# Add Q96794966: 268334, Q125191, 'Photograph'
# Add Q116282439: 323827, Q66018222, 'Cuneiform tablet'
# Add Q116374548: 38577, Q4817, 'Column'
# Add Q116371059: 2707, Q27667572, 'Cream pitcher'
# Add Q19919860: 490220, Q3305213, 'Painting'
# Add Q68352092: 81101, Q2144456, 'Evening dress'
# Add Q68352092: 81101, Q1908472, 'Evening dress'
# Add Q116348599: 9266, Q191851, 'Vase'
# Add Q3842520: 435614, Q3305213, 'Painting'
# Add Q116436613: 560573, Q28823, 'Linen fragment'
# Add Q116436613: 560573, Q11086567, 'Linen fragment'
# Add Q20201876: 472326, Q3305213, 'Tracery light'
# Add Q20178413: 11378, Q93184, 'Watercolor'
# Add Q19924635: 11055, Q3305213, 'Painting'
# Add Q97327122: 73214, Q1352349, 'Temple model'
# Add Q116297123: 240136, Q2413314, 'Jug'
# Add Q116370583: 3283, Q746549, 'Dish'
# Add Q19913103: 437232, Q3305213, 'Painting'
# Add Q116273175: 469063, Q168456, 'Earring'
# Add Q19924604: 11540, Q3305213, 'Watercolor'
# Add Q116431825: 556277, Q2442735, 'Scarab'
# Add Q98820256: 259857, Q125191, 'Photograph'
# Add Q96584906: 259651, Q125191, 'Photograph'
# Add Q116273637: 464227, Q506002, 'Crozier head'
# Add Q20199201: 486727, Q3305213, 'Print'
# Add Q20197351: 489407, Q3305213, 'Painting'
# Add Q116242772: 447008, Q1264081, 'Incense burner'
# Add Q116396812: 60646, Q191851, 'Vase'
# Add Q20195866: 485034, Q3305213, 'Painting'
# Add Q78919705: 36155, Q3305213, 'Album leaf'
# Add Q20167013: 436562, Q3305213, 'Painting, predella panel'
# Add Q116431976: 556390, Q2442735, 'Scarab'
# Add Q97581173: 294464, Q125191, 'Photograph'
# Add Q29385638: 503546, Q202027, 'Cornet à Pistons in B-flat'
# Add Q116273979: 468717, Q29401129, 'Statue head'
# Add Q116342388: 8022, Q3276479, 'Tongs'
# Add Q96358067: 653746, Q93184, 'Drawing'
# Add Q116424288: 553898, Q2442735, 'Scarab, Amenhotep II'
# Add Q100145704: 106619, Q635784, 'Ball gown'
# Add Q20171727: 13040, Q3305213, 'Painting, miniature'
# Add Q96748776: 123868, Q200539, 'Evening dress'
# Add Q116439087: 562609, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116365558: 5441, Q821952, 'Whale oil lamp'
# Add Q116247044: 465797, Q499916, 'Brooch'
# Add Q19920835: 486939, Q3305213, 'Painting'
# Add Q116392130: 4829, Q95966240, 'Looking glass'
# Add Q98224495: 11445, Q860861, 'Sculpture'
# Add Q116275981: 470705, Q2745866, 'Shaft'
# Add Q116399244: 199432, Q245005, 'Teapot'
# Add Q20189590: 491682, Q11060274, 'Print'
# Add Q20177368: 15068, Q3305213, 'Painting, miniature'
# Add Q60595333: 56799, Q18219090, 'Print'
# Add Q116293211: 246418, Q1066288, 'Statuette of a woman'
#   Q97732619: Error, Met ID should be exactly one. Instead: ['392605', '392606', '398726']
# Add Q97853418: 788339, Q11060274, 'Print'
# Add Q116373713: 45, Q262026, 'Andiron'
# Add Q97581156: 294446, Q125191, 'Photograph'
# Add Q116441729: 569439, Q2442735, 'Scarab'
# Add Q20194149: 486203, Q3305213, 'Painting'
# Add Q116274835: 562303, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116314394: 44336, Q18451251, 'Goblet'
# Add Q116398912: 197460, Q179700, 'Statue'
# Add Q100379739: 155933, Q4010399, 'Dressing Gown'
# Add Q116288797: 249443, Q153988, 'Bowl, ribbed'
# Add Q116398041: 196190, Q468402, 'Tile'
# Add Q100348941: 157993, Q535576, 'Bustle'
# Add Q116373106: 684, Q153988, 'Bowl'
# Add Q97581325: 286710, Q125191, 'Photographs'
# Add Q96357787: 491995, Q11060274, 'Print'
# Add Q116406023: 255629, Q838312, 'Pin'
#   Q116445584: Error, object name lookup with Met database returned empty
# Add Q116442807: 573952, Q2442735, 'Scarab, Amenhotep II'
# Add Q116363925: 6262, Q57216, 'Plate'
# Add Q116289065: 253796, Q2442735, 'Scaraboid'
# Add Q107180229: 57877, Q23490, 'Wine bottle'
# Add Q96634253: 491327, Q11060274, 'Print'
# Add Q97579689: 268038, Q125191, 'Photograph'
# Add Q116431095: 555709, Q1478508, 'Anklet'
# Add Q19924902: 10800, Q3305213, 'Painting'
# Add Q20194714: 486288, Q3305213, 'Painting'
# Add Q116242540: 252486, Q11086465, 'Neck-amphora'
# Add Q97786641: 789562, Q11060274, 'Print'
# Add Q116317190: 35885, Q14830135, 'Powder flask'
# Add Q19921330: 483667, Q3305213, 'Drawing'
# Add Q116306671: 235836, Q499916, 'Brooch'
# Add Q116297286: 244918, Q1665351, 'Intaglio'
# Add Q116373575: 235, Q63495428, 'Side chair'
# Add Q116392167: 4929, Q2892090, 'Mantel clock'
# Add Q116310212: 200968, Q833823, 'Beaker'
# Add Q116244267: 460568, Q1207302, 'Jar'
# Add Q19913838: 437785, Q3305213, 'Painting, miniature'
# Add Q20175871: 10519, Q3305213, 'Painting'
# Add Q58755570: 40508, Q3305213, 'Handscroll'
# Add Q58755570: 40508, Q5647631, 'Handscroll'
# Add Q19913588: 438415, Q3305213, 'Painting, lunette'
# Add Q116365785: 5281, Q386215, 'Mug'
# Add Q97581403: 301993, Q125191, 'Photograph'
# Add Q116440995: 568751, Q11086567, 'Vase fragment'
# Add Q116393284: 9920, Q1531435, 'Wine glass'
# Add Q20168386: 436075, Q3305213, 'Painting'
# Add Q116391916: 3771, Q1144689, 'Folding screen'
# Add Q97767963: 396559, Q11060274, 'Print'
# Add Q19912803: 437656, Q3305213, 'Painting'
# Add Q116240940: 29335, Q830004, 'Bit'
# Add Q20177167: 15273, Q3305213, 'Painting, miniature'
# Add Q116392740: 7318, Q1422576, 'Saucer'
# Add Q97013012: 291836, Q125191, 'Daguerreotype; Stereograph'
# Add Q19924391: 11034, Q3305213, 'Painting'
# Add Q20189642: 488893, Q3305213, 'Painting'
# Add Q19920996: 486398, Q3305213, 'Painting'
# Q29388316: AttributeError for object_name: nan
# Add Q78691886: 75035, Q3305213, 'Folio'
# Add Q116308170: 198569, Q17489160, 'Bust'
# Add Q96035521: 403910, Q1190417, 'Baseball card, photograph'
# Add Q116393458: 15328, Q35473, 'Window'
# Add Q97579810: 268125, Q125191, 'Photograph'
# Add Q116287394: 254494, Q1066288, 'Statuette of Aphrodite'
# Add Q116398018: 196054, Q81727, 'Standing cup with cover'
# Add Q78808599: 51581, Q3305213, 'Album'
# Add Q116296802: 244148, Q330946, 'Dagger blade'
# Add Q116434041: 559286, Q1422576, 'Model dish, Perneb'
# Add Q116281599: 557316, Q189299, 'Necklace'
# Add Q116442030: 569626, Q2442735, 'Scarab'
# Add Q104413110: 751513, Q11460, 'War shirt'
# Add Q116444417: 647607, Q535067, 'Sauceboat'
# Add Q78750968: 54686, Q3305213, 'Album leaf'
# Add Q99807246: 90832, Q2940816, 'Jacket'
# Add Q116411544: 476436, Q40843, 'Cross'
# Add Q19917458: 486652, Q3305213, 'Painting'
# Add Q29385661: 503675, Q180733, 'Mandolin'
# Add Q116277019: 547419, Q1643900, 'Arrowhead'
# Add Q96357647: 481727, Q93184, 'Drawing'
# Add Q96586096: 491739, Q93184, 'Drawing'
# Add Q116309845: 201769, Q29527347, 'Figure'
#   Q1755464: Error, Met ID should be exactly one. Instead: ['377282', '336223', '377283', '391255']
# Add Q98823969: 771461, Q125191, 'Photograph'
# Add Q116371239: 2554, Q11083119, 'Urn'
# Add Q116726658: 61405, Q35197, 'Mirror'
# Add Q116290088: 242007, Q48634, 'Sarcophagus, anthropoid'
# Add Q20200313: 487672, Q860861, 'Sculpture'
# Add Q116441397: 569050, Q11086567, 'Ring fragment, bezel'
# Add Q116441397: 569050, Q33269774, 'Ring fragment, bezel'
# Add Q116344658: 8390, Q245005, 'Teapot'
# Add Q19920945: 483201, Q3305213, 'Painting'
# Add Q116310110: 203403, Q11422, 'Toy'
# Add Q116392890: 8326, Q245005, 'Teapot'
# Add Q116295117: 246300, Q1066288, 'Statuette of Herakles'
# Add Q97852614: 775598, Q11060274, 'Print'
# Add Q116415668: 548785, Q39397, 'Ax'
# Add Q116289161: 249429, Q153988, 'Bowl, ribbed'
# Add Q116242483: 205520, Q151771, 'Candlestick'
# Add Q116390598: 1348, Q151771, 'Candlestick'
# Add Q20182735: 460924, Q10672725, 'Snuffbox'
# Add Q20182906: 459174, Q3305213, 'Painting'
# Add Q116362292: 6517, Q3391771, 'Platter'
# Add Q19923629: 487032, Q3305213, 'Painting'
# Add Q104413088: 717564, Q96091671, 'Water jar'
# Add Q96586136: 687752, Q595597, 'Negative'
# Add Q20176244: 10852, Q3305213, 'Painting'
# Add Q116345087: 9321, Q191851, 'Vase'
# Add Q116307566: 208284, Q245005, 'Teapot with cover'
# Add Q78752649: 54641, Q3305213, 'Album leaf'
# Add Q20187691: 461446, Q3305213, 'Frame'
# Add Q78714781: 72570, Q3305213, 'Hanging scroll'
# Add Q116291708: 248210, Q2442735, 'Scarab'
# Add Q116305274: 640179, Q101401, 'Bell'
# Add Q96181612: 268700, Q125191, 'Photograph'
# Add Q116438793: 562348, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q19923992: 10471, Q3305213, 'Painting'
# Add Q116364313: 5533, Q914149, 'Paperweight'
# Add Q96800561: 268343, Q125191, 'Photograph'
# Add Q104213113: 263168, Q125191, 'Photograph'
# Add Q116242737: 444600, Q404785, 'Ewer'
# Add Q116394444: 26556, Q23954892, 'Smallsword'
# Add Q116444941: 751615, Q188075, 'Box'
# Add Q116290030: 247561, Q1066288, 'Statuette of a woman'
# Add Q116438843: 562399, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116394205: 22925, Q23954892, 'Smallsword'
# Add Q18627442: 285461, Q125191, 'Photograph'
# Add Q116338503: 7575, Q131514, 'Sofa'
# Add Q78852068: 44625, Q3305213, 'Hanging scroll'
# Add Q116432142: 556517, Q2442735, 'Scarab'
# Add Q19930626: 11891, Q18761202, 'Watercolor'
# Add Q116272717: 587763, Q162919, 'Sealing'
# Add Q116306151: 236768, Q201664, 'Bracelet'
# Add Q20201192: 466589, Q860861, 'Statuette'
# Add Q19922230: 492554, Q3305213, 'Drawing'
# Add Q78620855: 670923, Q3305213, 'Handscroll'
# Add Q116331497: 9154, Q16180001, 'Tumbler'
# Add Q19914004: 435800, Q3305213, 'Painting, miniature'
# Add Q116273249: 469030, Q95870182, 'Strap end'
# Add Q116393644: 19869, Q191851, 'Vase'
# Add Q29384647: 335240, Q93184, 'Drawing'
# Add Q20200883: 471061, Q3305213, 'Fresco fragment'
# Add Q116241548: 45634, Q987767, 'Wine container'
# Add Q116365717: 5333, Q386215, 'Cann'
# Add Q116432634: 557229, Q11086567, 'Vase fragment'
# Add Q116438810: 562366, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q20188314: 462594, Q3305213, 'Bowl'
# Add Q116240827: 191804, Q179700, 'Statue'
# Add Q116371271: 2534, Q107444, 'Teakettle'
# Add Q59590708: 334324, Q93184, 'Drawing'
# Add Q116390411: 1025, Q499916, 'Brooch'
# Add Q116394183: 22759, Q830004, 'Bit'
# Add Q116244429: 466185, Q2111434, 'Harness pendant'
# Add Q116309672: 197563, Q245005, 'Teapot'
# Add Q19920718: 484433, Q3305213, 'Painting'
# Add Q116310691: 194293, Q6806674, 'Pharmacy jar'
# Add Q78722434: 57350, Q3305213, 'Painted panel'
# Add Q116405261: 254859, Q178401, 'Amphora'
# Add Q96185389: 557766, Q3305213, 'Facsimile, Pairy (TT 139), funeral'
# Add Q116445175: 810946, Q201664, 'Bracelet'
# Add Q20178068: 12730, Q18761202, 'Watercolor'
# Add Q116297172: 240101, Q668349, 'Kylix'
# Add Q116432217: 556581, Q5174015, 'Kohl jar'
# Add Q78699534: 74997, Q3305213, 'Folio'
# Add Q116363579: 6431, Q57216, 'Plate'
# Add Q116324553: 18238, Q81895, 'Spoon'
# Add Q116272795: 464380, Q57216, 'Plate'
# Add Q78841934: 45703, Q3305213, 'Painting'
# Add Q116392760: 7343, Q6653030, 'Sconce'
# Add Q116246026: 460160, Q1888893, 'Albarello'
# Add Q96185525: 764083, Q11060274, 'Valentine'
# Add Q19913738: 439273, Q3305213, 'Painting, drawing'
# Add Q98820342: 261120, Q125191, 'Photograph'
# Add Q19924525: 15036, Q3305213, 'Painting, miniature'
# Add Q20172673: 11712, Q3305213, 'Painting'
# Add Q116390505: 1209, Q151771, 'Candlestick'
# Add Q116311454: 193707, Q2111434, 'Pendant'
# Add Q116247992: 471807, Q746549, 'Dish'
# Add Q116401496: 240365, Q81727, 'Cup'
# Add Q116353736: 6038, Q57216, 'Plate'
# Add Q116250567: 39317, Q1497375, 'Architectural ensemble'
# Add Q116250567: 39317, Q43694649, 'Architectural ensemble'
# Add Q96185419: 557814, Q3305213, 'Facsimile, Panehsy (TT 16), Amenhotep I, palanquin, sphinx; Drink-and-be-Merry'
# Add Q116287163: 255529, Q831869, 'Oinochoe'
# Add Q116372400: 1309, Q151771, 'Candlestick'
# Add Q19923427: 485188, Q3305213, 'Painting'
# Add Q20197683: 488614, Q3305213, 'Painting'
# Add Q116404180: 252487, Q11086465, 'Neck-amphora'
# Add Q116402254: 245833, Q245117, 'Stucco relief'
# Add Q97012694: 286410, Q125191, 'Photograph'
# Add Q116306978: 206458, Q57216, 'Plate'
# Add Q116280529: 467630, Q179700, 'Statue'
# Add Q19913751: 435699, Q3305213, 'Painting, miniature'
# Add Q116371824: 2010, Q14169227, 'Chest of drawers'
# Add Q116441045: 568793, Q11086567, 'Vase fragment'
# Add Q116275418: 561835, Q28823, 'Linen Mark'
# Add Q116310558: 195910, Q81727, 'Standing cup with cover'
# Add Q116310694: 197810, Q22075301, 'Length'
# Add Q116295088: 248087, Q548275, 'Candelabrum'
# Add Q116341254: 7474, Q7500017, 'Shoe buckle'
# Add Q116393195: 9463, Q191851, 'Vase'
# Add Q100347782: 139874, Q200539, 'Dress'
# Add Q116287937: 257433, Q3305213, 'Portrait of a woman'
# Add Q20197048: 486611, Q3305213, 'Painting'
# Add Q116295618: 246220, Q746549, 'Dish'
# Add Q116432083: 556470, Q2442735, 'Scarab'
# Add Q19925607: 18447, Q3305213, 'Painting'
# Add Q20187123: 459071, Q3305213, 'Painting'
# Add Q96053338: 404438, Q1190417, 'Baseball card, photograph'
# Add Q116371439: 2397, Q1207302, 'Jar'
# Add Q116393050: 8923, Q2569925, 'Trivet'
# Add Q116404864: 254457, Q2442735, 'Scaraboid'
# Add Q112063538: 44887, Q720106, 'Handscroll'
# Add Q116389794: 63387, Q11060274, 'Print'
#   Q29388417: Error, object name lookup with Met database returned empty
# Add Q116370601: 3256, Q746549, 'Dish'
# Add Q116305545: 239700, Q2413314, 'Jug'
# Add Q78723188: 57318, Q3305213, 'Hanging scroll'
# Add Q19913977: 435999, Q3305213, 'Painting, miniature'
# Add Q116441828: 569489, Q2442735, 'Scarab'
# Add Q116395467: 42212, Q80228, 'Bottle'
# Add Q40432: 435702, Q3305213, 'Painting'
# Add Q116385568: 449102, Q193893, 'Capital'
# Add Q19917457: 488783, Q3305213, 'Painting'
# Add Q116445097: 771051, Q153988, 'Bowl'
# Q29388312: AttributeError for object_name: nan
# Add Q20172045: 13357, Q3305213, 'Painting'
# Add Q96807171: 284029, Q125191, 'Photograph'
# Add Q116444018: 625715, Q726826, 'Shabti, worker, Nauny'
# Add Q63362066: 44943, Q18219090, 'Print'
# Add Q19924771: 12707, Q3305213, 'Painting'
# Add Q78693459: 75027, Q3305213, 'Folio'
# Add Q20201763: 471926, Q179700, 'Statue'
# Add Q116298713: 644896, Q29401129, 'Statue head'
#   Q97579707: Error, object name lookup with Met database returned empty
# Add Q116441049: 568798, Q11086567, 'Vase fragment'
# Add Q19919531: 632936, Q3305213, 'Painting'
# Add Q116308418: 208003, Q131647, 'Medal'
# Add Q116306109: 236772, Q2111434, 'Pendant brooch'
# Add Q116306109: 236772, Q499916, 'Pendant brooch'
# Add Q116396317: 49862, Q191851, 'Vase'
# Add Q96185496: 693833, Q11060274, 'Print'
# Add Q116246222: 591033, Q726826, 'Shabti, Henettawy C'
# Add Q19905313: 435745, Q3305213, 'Painting'
# Add Q20195689: 482999, Q3305213, 'Painting'
# Add Q19923116: 486653, Q3305213, 'Drawing'
# Add Q78709064: 74682, Q3305213, 'Drawing'
# Add Q20198658: 484425, Q3305213, 'Painting'
# Add Q116440513: 568167, Q4364339, 'Foundation Deposit Plaque, rectangular'
# Add Q83560018: 379, Q833823, 'Beaker'
# Add Q19925507: 13176, Q18761202, 'Watercolor'
# Add Q61363155: 788905, Q3305213, 'Painting'
# Add Q116246710: 552601, Q131557, 'Amulet, Taweret'
# Add Q116314812: 40116, Q7295963, 'Rattle'
# Add Q97012940: 291819, Q125191, 'Daguerreotype'
# Add Q78822848: 49463, Q3305213, 'Folding fan mounted as an album leaf'
# Add Q98821522: 289506, Q125191, 'Photograph'
# Add Q116393309: 9971, Q1531435, 'Wine glass'
# Add Q20194594: 486239, Q3305213, 'Painting'
# Add Q116289228: 248527, Q11086567, 'Vase fragment'
# Add Q96802952: 269462, Q125191, 'Photograph'
# Add Q78742564: 54974, Q3305213, 'Hanging scroll'
# Add Q29384395: 318764, Q860861, 'Couple figure'
# Add Q19924032: 12169, Q18761202, 'Watercolor'
# Add Q19924032: 12169, Q93184, 'Watercolor'
# Add Q116357446: 6776, Q29527347, 'Figure'
# Add Q97852881: 787707, Q11060274, 'Print'
# Add Q78995779: 36048, Q3305213, 'Handscroll'
# Add Q97770783: 739023, Q11060274, 'Print'
# Add Q116445572: 852566, Q11060274, 'Print'
# Add Q116431000: 555640, Q245117, 'Relief'
# Add Q116392307: 5503, Q678883, 'Paneling'
# Add Q96756837: 653751, Q93184, 'Drawing'
# Add Q97732265: 389075, Q11060274, 'Print'
# Add Q96181592: 266258, Q125191, 'Photograph'
# Add Q19913048: 435832, Q3305213, 'Painting'
# Add Q116393509: 16817, Q499916, 'Brooch'
# Add Q116288245: 248673, Q1066288, 'Statuette of Herakles'
# Add Q97852598: 775517, Q11060274, 'Print'
# Add Q20176973: 16725, Q3305213, 'Painting, miniature'
# Add Q116393369: 12960, Q335261, 'Ornament'
# Add Q19925475: 11518, Q3305213, 'Painting'
# Add Q100709862: 107712, Q200539, 'Dress'
# Add Q97012665: 286280, Q125191, 'Photograph'
# Add Q20191234: 653753, Q3305213, 'Painting'
# Add Q19917872: 486949, Q3305213, 'Drawing'
# Add Q98823538: 285345, Q125191, 'Photograph'
# Add Q83562802: 80389, Q200539, 'Dress'
# Add Q116280200: 447966, Q11086567, 'Fragment'
# Add Q19924550: 15169, Q3305213, 'Painting, miniature'
# Add Q78626108: 473058, Q3305213, 'Painting'
# Add Q116314304: 42088, Q29527347, 'Figure'
# Add Q116370462: 3411, Q10550521, 'Parlor'
# Add Q78871177: 39569, Q3305213, 'Handscroll'
# Add Q97579616: 267979, Q125191, 'Photograph'
# Add Q116390310: 639, Q80228, 'Bottle'
# Add Q116371018: 8411, Q245005, 'Teapot'
# Add Q116275421: 468397, Q2413314, 'Jug'
# Add Q116444345: 625931, Q726826, 'Shabti, worker, Nauny'
# Add Q116288028: 251448, Q717954, 'Aryballos'
# Add Q96035645: 403981, Q1190417, 'Baseball card, photograph'
# Add Q19905372: 437382, Q3305213, 'Painting'
# Add Q116291696: 245454, Q673338, 'Alabastron'
# Add Q55594040: 439977, Q3305213, 'Painting'
# Add Q97732020: 388773, Q11060274, 'Print'
# Add Q101483072: 335080, Q93184, 'Drawing'
# Add Q116310258: 207238, Q10672725, 'Snuffbox'
# Add Q96183025: 291552, Q125191, 'Photogram'
# Add Q116295490: 247190, Q717954, 'Aryballos'
# Add Q116373889: 230934, Q1066288, 'Statuette'
# Add Q116247923: 451041, Q153988, 'Bowl'
# Add Q96185502: 696209, Q11060274, 'Print'
# Add Q83562253: 40509, Q5647631, 'Handscroll'
# Add Q116297493: 244889, Q1665351, 'Intaglio'
# Add Q19905144: 437676, Q3305213, 'Painting'
# Add Q98823874: 659461, Q192425, 'Postcard'
# Add Q19917561: 483157, Q3305213, 'Drawing'
# Add Q97579681: 268031, Q125191, 'Photograph'
# Add Q116440467: 568130, Q224104, 'Foundation Deposit Plaque, cartouche'
# Add Q116440467: 568130, Q4364339, 'Foundation Deposit Plaque, cartouche'
# Add Q116273107: 469160, Q231455, 'Solidus'
# Add Q116402821: 251079, Q153988, 'Bowl'
# Add Q96357836: 495256, Q93184, 'Drawing'
# Add Q116282541: 322488, Q245117, 'Relief'
# Add Q116441344: 569005, Q46847, 'Ring'
# Add Q116392366: 5988, Q57216, 'Plate'
# Add Q116273204: 569311, Q46847, 'Ring'
# Add Q78829204: 49075, Q3305213, 'Hanging scroll'
# Add Q96793337: 261483, Q125191, 'Photograph'
# Add Q116414766: 546641, Q1053956, 'Bead'
# Add Q96800589: 268355, Q125191, 'Photograph'
# Add Q96183061: 291561, Q125191, 'Photogram'
# Add Q116359665: 5802, Q132397, 'Pitcher'
# Add Q20177038: 15202, Q3305213, 'Painting, miniature'
# Add Q98821241: 269899, Q125191, 'Photograph'
# Add Q116289355: 254935, Q960844, 'Cinerary urn'
# Add Q116371128: 2657, Q60310748, 'Cream pot'
# Add Q78752565: 54642, Q3305213, 'Album leaf'
# Add Q78737314: 57173, Q3305213, 'Hanging scroll'
# Add Q20200676: 488016, Q46847, 'Ring'
# Add Q116240881: 43946, Q101401, 'Bell'
# Add Q78638736: 438126, Q3305213, 'Painting'
# Add Q20171749: 13049, Q3305213, 'Painting'
# Add Q116370576: 3288, Q746549, 'Dish'
# Add Q116392621: 6867, Q46847, 'Ring'
# Add Q83562043: 37620, Q29527347, 'Figure'
# Add Q78702205: 74911, Q3305213, 'Folio'
# Add Q95986506: 3979, Q1326509, 'Girandole'
# Add Q20177850: 21655, Q860861, 'Sculpture'
# Add Q116287776: 251529, Q65769142, 'Stamp'
# Add Q116295794: 240727, Q191851, 'Vase'
# Add Q96181408: 157153, Q200539, 'Evening dress'
# Add Q96035651: 404084, Q1190417, 'Baseball card, photograph'
# Add Q29961418: 694642, Q3305213, 'Painting'
# Add Q116289563: 249317, Q746549, 'Dish'
# Add Q116307293: 207103, Q29527347, 'Figure'
# Add Q116444735: 718117, Q914149, 'Paperweight'
# Add Q19921206: 491762, Q3305213, 'Drawing'
# Add Q116392496: 6351, Q57216, 'Plate'
# Add Q116373095: 692, Q153988, 'Bowl'
# Add Q20198222: 490814, Q3305213, 'Painting'
# Add Q97771754: 736914, Q11060274, 'Print'
# Add Q116296970: 240181, Q1136095, 'Skyphos'
# Add Q97771900: 742650, Q11060274, 'Print'
# Add Q97579072: 259606, Q1757923, 'Carte-de-visite'
# Add Q116310125: 195414, Q622360, 'Commode'
# Add Q116370487: 3387, Q979617, 'Egg cup'
# Add Q116395217: 40744, Q191851, 'Vase'
# Add Q59567425: 55138, Q18219090, 'Print'
# Add Q116297358: 239989, Q178401, 'Amphora'
# Add Q116442939: 575880, Q131557, 'Amulet, Djed pillar'
# Add Q20201160: 471972, Q3305213, 'Game piece'
# Add Q116290048: 245616, Q15407662, 'Calyx-krater'
# Add Q78796696: 51769, Q3305213, 'Handscroll'
# Add Q116295596: 247176, Q476968, 'Krater'
# Add Q20173464: 12578, Q3305213, 'Painting'
# Add Q97827134: 843780, Q11060274, 'Print'
# Add Q116405697: 255352, Q745783, 'Hydria, kalpis'
# Add Q116321043: 38612, Q746549, 'Dish'
# Add Q116293703: 249814, Q673338, 'Alabastron'
# Add Q20191789: 490226, Q3305213, 'Drawing'
# Add Q19918451: 493196, Q3305213, 'Drawing'
# Add Q20199045: 488428, Q3305213, 'Drawing'
# Add Q96585956: 491314, Q11060274, 'Print'
# Add Q116392900: 8442, Q81895, 'Spoon'
# Add Q19905214: 437222, Q3305213, 'Painting'
# Add Q116244226: 473637, Q83893, 'Ingot'
# Add Q20201888: 471996, Q3305213, 'Reliquary bust'
# Add Q97853048: 788045, Q11060274, 'Print'
# Add Q116373917: 208538, Q17489160, 'Bust'
# Add Q116289042: 248560, Q11086567, 'Vase fragment'
# Add Q19920227: 487051, Q860861, 'Sculpture'
# Add Q116409596: 449798, Q153988, 'Bowl'
# Add Q29385199: 452112, Q1363377, 'Folio from an illustrated manuscript'
# Add Q29385199: 452112, Q678664, 'Folio from an illustrated manuscript'
# Add Q116444388: 628198, Q860861, 'Sculpture'
# Add Q97854178: 811999, Q11060274, 'Print'
# Add Q100347117: 82144, Q2001719, 'Pelisse'
# Add Q19914234: 436683, Q3305213, 'Painting'
# Add Q20187058: 459060, Q3305213, 'Painting'
# Add Q116374348: 39950, Q245117, 'Relief fragment'
# Add Q116274121: 449135, Q11086567, 'Tile fragment'
# Add Q116274121: 449135, Q468402, 'Tile fragment'
# Add Q116333909: 7763, Q81895, 'Spoon'
# Add Q97827132: 843777, Q11060274, 'Print'
# Add Q116432256: 556617, Q2442735, 'Scarab'
# Add Q116370781: 2976, Q50386939, 'Curtain knob'
# Add Q116242507: 205428, Q191851, 'Vase'
# Add Q116307573: 207022, Q1066288, 'Statuette'
# Add Q97852296: 775461, Q11060274, 'Print'
# Add Q116401331: 237993, Q63495428, 'Side chair'
# Add Q20198011: 492374, Q22075301, 'Textile'
# Add Q20198011: 492374, Q29639251, 'Textile'
# Add Q116371440: 2396, Q1207302, 'Jar'
# Add Q20186249: 459170, Q3305213, 'Painting'
# Add Q20181217: 460417, Q193220, 'Fan'
# Add Q100709758: 106979, Q200539, 'Morning dress'
# Add Q19913317: 437140, Q3305213, 'Painting, miniature'
# Add Q20170044: 12471, Q3305213, 'Painting'
# Add Q78700174: 74992, Q3305213, 'Folio'
# Add Q20190830: 488481, Q3305213, 'Painting'
# Add Q116365368: 5463, Q821952, 'Whale oil lamp'
# Add Q116313667: 50321, Q46847, 'Ring'
# Add Q116411788: 484698, Q548275, 'Candelabrum'
# Add Q116441829: 569490, Q2442735, 'Scarab'
# Add Q116397387: 186460, Q80228, 'Bottle'
# Add Q116314231: 42746, Q33163, 'Stool'
# Add Q97788363: 811148, Q11060274, 'Print'
# Add Q19911948: 439118, Q3305213, 'Painting'
# Add Q83562472: 44881, Q2741056, 'Cabinet'
# Add Q116242796: 446176, Q1363377, 'Folio from a non-illustrated manuscript'
# Add Q116726667: 43248, Q1066288, 'Figures'
# Add Q116326639: 22000, Q50414774, 'Armor'
# Add Q116280558: 461628, Q860792, 'Frame'
# Add Q116367677: 4005, Q11086567, 'Fragment'
# Add Q96357609: 354212, Q53731850, 'Book'
# Add Q116287868: 251506, Q838312, 'Pin'
# Add Q116441382: 569039, Q11086567, 'Ring fragment, bezel'
# Add Q116441382: 569039, Q33269774, 'Ring fragment, bezel'
# Add Q116370454: 3422, Q2106696, 'Dressing table'
# Add Q19904878: 436929, Q3305213, 'Painting'
# Add Q116289352: 245723, Q1350279, 'Pyxis with lid'
# Add Q116289352: 245723, Q2488579, 'Pyxis with lid'
# Add Q20201995: 479575, Q3305213, 'Manuscript leaf'
# Add Q116373552: 1879, Q63495428, 'Side Chair'
# Add Q116391925: 3785, Q16180001, 'Tumbler'
# Add Q78741380: 55297, Q3305213, 'Hanging scroll'
# Add Q116400941: 209068, Q2356786, 'Sugar bowl'
# Add Q116371972: 1763, Q11285759, 'Armchair'
# Add Q98822541: 261740, Q125191, 'Photograph'
# Add Q116374471: 38980, Q29527347, 'Figure'
# Add Q116272608: 550318, Q2442735, 'Scarab, Ramesses II'
# Add Q97579661: 268018, Q125191, 'Photograph'
# Add Q19921137: 484866, Q3305213, 'Drawing'
# Add Q79013381: 16744, Q3305213, 'Painting'
# Add Q20198996: 484504, Q3305213, 'Drawing'
# Add Q116244526: 473290, Q2111434, 'Pendant'
# Add Q19911828: 437596, Q3305213, 'Painting, drawing'
# Add Q116252455: 471146, Q4817, 'Column'
# Add Q116422156: 553565, Q1053956, 'Bead'
# Add Q116276356: 478988, Q132397, 'Pitcher'
# Add Q116252710: 470981, Q193893, 'Capital'
# Add Q116370217: 3727, Q18696213, 'Flask'
# Add Q116310341: 197478, Q1066288, 'Statuette group'
# Add Q116310341: 197478, Q1497375, 'Statuette group'
# Add Q19924243: 12612, Q3305213, 'Painting, miniature'
# Add Q20184499: 459073, Q3305213, 'Painting'
# Add Q78795628: 51800, Q3305213, 'Handscroll'
# Add Q116393095: 8956, Q2569925, 'Trivet'
# Add Q19917730: 632986, Q3305213, 'Painting'
# Add Q116274933: 562205, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116366068: 4856, Q95966240, 'Looking glass'
# Add Q116355639: 5971, Q57216, 'Plate'
# Add Q116367352: 4262, Q29527347, 'Figure'
# Add Q78618681: 670974, Q3305213, 'Albums'
# Add Q116370552: 3315, Q746549, 'Dish'
# Add Q116373691: 88, Q262026, 'Andiron'
# Add Q19924396: 19228, Q3305213, 'Watercolor'
# Add Q20198703: 485076, Q3305213, 'Drawing'
# Add Q116357728: 6719, Q3579073, 'Porringer'
# Add Q96585017: 371999, Q11060274, 'Print'
# Add Q96635156: 650159, Q125191, 'Photograph'
# Add Q116306598: 236108, Q622360, 'Commode'
# Add Q116434253: 559320, Q1422576, 'Model dish, Perneb'
# Add Q96357645: 383685, Q11060274, 'Print'
# ...
# Add Q116281847: 452064, Q191851, 'Vase'
# Add Q20188105: 460529, Q404785, 'Pitcher'
# Add Q20189686: 483873, Q3305213, 'Painting'
# Add Q97579192: 267890, Q125191, 'Photograph'
# Add Q20198980: 484416, Q3305213, 'Painting'
# Add Q116288590: 248584, Q1350279, 'Pyxis'
# Add Q116295800: 240653, Q80228, 'Bottle'
# Add Q116243366: 556601, Q188075, 'Box, cosmetic'
# Add Q19925498: 19301, Q3305213, 'Painting'
# Add Q116242630: 444985, Q404785, 'Ewer'
# Add Q116252871: 470845, Q193893, 'Capital'
# Add Q19923947: 10858, Q3305213, 'Painting'
# Add Q20196843: 485196, Q3305213, 'Painting'
# Add Q100706248: 90871, Q29353484, 'Ensemble'
# Add Q116235288: 548462, Q746549, 'Dish'
# Add Q116370971: 2764, Q81727, 'Cup'
# Add Q116370578: 3284, Q746549, 'Dish'
# Add Q116310736: 196470, Q1066288, 'Statuette'
# Add Q116351832: 6113, Q57216, 'Plate'
# Add Q116295295: 248059, Q208041, 'Sestertius'
# Add Q116400873: 208344, Q746549, 'Dish'
# Add Q116335049: 9000, Q16180001, 'Tumbler'
# Add Q61876908: 65008, Q559065, 'Robe'
# Add Q98821562: 296315, Q125191, 'Photograph'
# Add Q20198732: 486158, Q14745, 'Sculpture'
# Add Q19913053: 436192, Q3305213, 'Painting'
# Add Q19920249: 495130, Q3305213, 'Painting'
# Add Q116439037: 562565, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116335986: 7674, Q87718085, 'Soup plate'
# Add Q96195274: 765823, Q11060274, 'Valentine'
# Add Q116289466: 247656, Q11086567, 'Vase fragment'
# Add Q19911487: 437795, Q3305213, 'Painting'
# Add Q116402216: 243953, Q153988, 'Bowl'
# Add Q116364610: 6191, Q57216, 'Plate'
# Add Q116310610: 201414, Q115488, 'Medallion'
# Add Q20172966: 19272, Q3305213, 'Painting'
# Add Q116340830: 8107, Q81895, 'Spoon'
#   Q19918832: Error, object name lookup with Met database returned empty
# Add Q100347224: 86871, Q200539, 'Dress'
# Add Q116373226: 573, Q468402, 'Tile'
# Add Q20167172: 437331, Q3305213, 'Painting'
# Add Q116288970: 250095, Q1350279, 'Pyxis with lid'
# Add Q116288970: 250095, Q2488579, 'Pyxis with lid'
# Add Q116404154: 252456, Q921668, 'Stater'
# Add Q116234844: 21975, Q173603, 'Helmet'
# Add Q96182178: 291522, Q841954, 'Photogram'
# Add Q78760445: 53210, Q3305213, 'Hanging scroll'
# Add Q116242792: 445026, Q1348059, 'Panel'
# Add Q116441663: 569371, Q46847, 'Ring'
# Add Q20170003: 10467, Q3305213, 'Painting'
# Add Q116295565: 240834, Q2413314, 'Jug'
# Add Q97788731: 811332, Q11060274, 'Print'
# Add Q100706427: 108156, Q29353484, 'Ensemble'
# Add Q96035571: 403934, Q1190417, 'Baseball card, photograph'
# Add Q19912215: 436221, Q3305213, 'Painting'
# Add Q98822705: 265159, Q125191, 'Multiple exposure; Photograph'
# Add Q116292145: 245394, Q153988, 'Bowl'
# Add Q116374394: 39161, Q29527347, 'Figure'
# Add Q20201559: 471104, Q3305213, 'Roundel'
# Add Q116374462: 39007, Q29527347, 'Figure'
# Add Q29385311: 459198, Q17379525, 'Plate'
# Add Q29385901: 547687, Q15026, 'Chair, Reniseneb'
# Add Q19912739: 437750, Q3305213, 'Painting'
# Add Q116353716: 6040, Q57216, 'Plate'
# Add Q116372365: 1339, Q151771, 'Candlestick'
# Add Q110026460: 846917, Q15026, 'Chair'
# Add Q78861296: 40303, Q3305213, 'Handscroll'
# Add Q78861296: 40303, Q5647631, 'Handscroll'
# Add Q19917488: 488668, Q3305213, 'Painting'
# Add Q116393010: 8892, Q2569925, 'Trivet'
# Add Q20185347: 458974, Q3305213, 'Painting'
# Add Q83560072: 5401, Q189299, 'Necklace'
# Add Q96035418: 403788, Q1190417, 'Baseball card, photograph'
# Add Q116296967: 248703, Q860861, 'Head of a youth'
# Add Q116400225: 204635, Q11285759, 'Armchair'
# Add Q96195289: 765075, Q11060274, 'Valentine'
# Add Q116290093: 245601, Q1136095, 'Skyphos'
# Add Q20185104: 459409, Q3305213, 'Drawing'
# Add Q97854120: 811952, Q11060274, 'Print'
# Add Q116365757: 5307, Q386215, 'Mug'
# Add Q116246021: 460161, Q57216, 'Plate'
# Add Q116243399: 556508, Q1123756, 'Cylinder seal'
# Add Q116235489: 470294, Q499916, 'Brooch'
# Add Q97786668: 810828, Q11060274, 'Print'
# Add Q96634258: 491352, Q11060274, 'Print'
# Add Q116431889: 556323, Q2442735, 'Scarab'
# Add Q116372038: 1661, Q15026, 'Chair'
# Add Q20199469: 495271, Q93184, 'Drawing'
# Add Q116431979: 556392, Q2442735, 'Scarab'
# Add Q100706409: 107957, Q200539, 'Dress'
# Add Q29385086: 449211, Q321053, 'Panel'
# Add Q116307359: 209246, Q115488, 'Medallion'
# Add Q17813915: 436619, Q3305213, 'Painting'
# Add Q116316575: 40609, Q11086567, 'Fragment'
# Add Q79000696: 36008, Q3305213, 'Fan mounted as an album leaf'
# Add Q116306347: 231605, Q81895, 'Spoon'
# Add Q116275353: 561876, Q28823, 'Linen Mark'
# Add Q97581365: 294724, Q125191, 'Photograph'
# Add Q78850435: 44983, Q3305213, 'Hanging scroll'
# Add Q96748809: 457790, Q3305213, 'Painting'
# Add Q116307193: 207149, Q29527347, 'Figure'
# Add Q116429566: 555311, Q131557, 'Amulet'
# Add Q116310201: 193555, Q81727, 'Cup with cover'
# Add Q116310201: 193555, Q2488579, 'Cup with cover'
# Add Q116429705: 555329, Q131557, 'Amulet'
# Add Q116390624: 1365, Q151771, 'Candlestick'
# Add Q83562533: 49805, Q2188827, 'Hanging scroll'
# Add Q20177805: 14307, Q3305213, 'Painting, miniature'
# Add Q116274030: 464111, Q95870182, 'Strap end'
# Add Q116376748: 38480, Q4364339, 'Votive plaque'
# Add Q116245572: 451368, Q1125338, 'Bookbinding'
# Add Q116358959: 5820, Q60310748, 'Cream pot'
# Add Q116341479: 7456, Q1135567, 'Buckle'
# Add Q116342920: 7351, Q6653030, 'Sconce'
# Add Q19913136: 437687, Q3305213, 'Painting'
# Add Q116445107: 773198, Q499916, 'Brooch'
# Add Q116372289: 1418, Q53688576, 'Card table'
# Add Q96053320: 404415, Q1190417, 'Baseball card, photograph'
# Add Q29385430: 466296, Q184856, 'Pointer tip'
# Add Q19923924: 15151, Q3305213, 'Painting, miniature'
# Add Q96585969: 491334, Q11060274, 'Print'
# Add Q78851100: 44861, Q3305213, 'Hanging scroll'
# Add Q19911951: 438676, Q3305213, 'Painting'
# Add Q116359966: 6640, Q29527347, 'Figure'
# Add Q116390318: 643, Q80228, 'Bottle'
# Add Q19911580: 436941, Q3305213, 'Painting'
# Add Q78829060: 49080, Q3305213, 'Hanging scroll'
# Add Q78878147: 37981, Q3305213, 'Folio'
# Add Q116331845: 7796, Q81895, 'Spoon'
# Add Q78693897: 75025, Q3305213, 'Folio'
# Add Q19920652: 489238, Q3305213, 'Painting'
# Add Q19911968: 436068, Q3305213, 'Painting'
# Add Q116295585: 240787, Q153988, 'Bowl'
#   Q20168393: Error, object name lookup with Met database returned empty
# Add Q78710847: 74648, Q3305213, 'Painting'
# Add Q116400183: 204273, Q1066288, 'Statuette'
# Add Q116280486: 546974, Q726826, 'Shabti'
# Add Q116356770: 5887, Q132397, 'Pitcher'
# Add Q19913793: 436466, Q3305213, 'Painting, miniature'
# Add Q97853198: 788317, Q11060274, 'Print'
# Add Q78811900: 51526, Q3305213, 'Handscroll'
# Add Q78802652: 51682, Q3305213, 'Album leaf'
# Add Q78851553: 44794, Q3305213, 'Wall painting'
# Add Q83562019: 32368, Q860861, 'Sculpture'
# Add Q20176591: 635395, Q3305213, 'Painting'
# Add Q78694908: 75020, Q3305213, 'Folio'
# Add Q78725638: 57279, Q3305213, 'Drawing'
# Add Q116414862: 546780, Q6105860, 'Headrest'
# Add Q20200796: 483133, Q3305213, 'Drawing'
# Add Q116370388: 3521, Q979617, 'Egg cup'
# Add Q116294741: 241030, Q860861, 'Head of a man'
# Add Q19913446: 437567, Q3305213, 'Painting, icons'
# Add Q19911462: 436669, Q3305213, 'Painting'
# Add Q78884019: 37876, Q3305213, 'Painting'
# Add Q116253152: 457133, Q41207, 'Coin'
# Add Q116374406: 39128, Q29527347, 'Figure'
# Add Q20201619: 471029, Q21061279, 'Stained glass panel'
# Add Q106357246: 12056, Q3305213, 'Watercolor'
# Add Q19911611: 437157, Q3305213, 'Painting'
# Add Q20173718: 12705, Q3305213, 'Painting'
# Add Q98823228: 267534, Q125191, 'Photograph'
# Add Q116244032: 451713, Q153988, 'Bowl'
# Add Q96053651: 412450, Q1190417, 'Baseball card'
# Add Q116402704: 250952, Q831869, 'Oinochoe'
# Add Q116385368: 444864, Q41207, 'Coin'
# Add Q116365895: 4975, Q4364339, 'Plaque'
# Add Q96185384: 557761, Q3305213, 'Facsimile, Amenemhat Surer (TT 48), inscription'
# Add Q62589709: 78633, Q18219090, 'Illustrated books'
# Add Q19923812: 11471, Q3305213, 'Painting'
# Add Q97786633: 789556, Q11060274, 'Print'
# Add Q75196935: 11271, Q12043905, 'Drawing'
# Add Q96586115: 687741, Q595597, 'Negative'
# Add Q96399251: 830456, Q860861, 'Sculpture'
# Add Q116255989: 470674, Q2745866, 'Shaft'
# Add Q116355514: 5968, Q57216, 'Plate'
# Add Q19917729: 489404, Q3305213, 'Painting'
# Add Q78833767: 48946, Q3305213, 'Hanging scroll'
# Add Q97417807: 208052, Q3666631, 'Secretary'
# Add Q96185302: 544639, Q3305213, 'Facsimile, Rekhmire (TT 100), carpenters'
# Add Q78880295: 37947, Q3305213, 'Folio'
# Add Q116244880: 466117, Q153988, 'Bowl'
# Add Q116366819: 4480, Q1207302, 'Jar'
# Add Q97581385: 301937, Q125191, 'Photograph'
# Add Q97850021: 757600, Q11060274, 'Print'
# Add Q116288560: 254269, Q673338, 'Alabastron'
# Add Q19917824: 488623, Q3305213, 'Painting'
# Add Q20200701: 495377, Q499916, 'Brooch'
# Add Q116247985: 451028, Q163446, 'Carpet'
# Add Q116289678: 248409, Q860861, 'Head of a woman'
# Add Q116396335: 49914, Q191851, 'Vase'
# Add Q116256148: 472335, Q208454, 'Abacus'
# Add Q97012955: 291834, Q125191, 'Daguerreotype'
# Add Q116310088: 199030, Q153988, 'Bowl'
# Add Q116370833: 2934, Q18349459, 'Cup plate'
# Add Q100145588: 81790, Q11284623, 'Afternoon dress'
# Add Q116276485: 452937, Q1363377, 'Folio from an illustrated manuscript'
# Add Q116275431: 468395, Q2413314, 'Jug'
# Add Q116440871: 568595, Q15148, 'Spatula'
# Add Q19920176: 482809, Q3305213, 'Painting'
# Add Q116340387: 8117, Q81895, 'Spoon'
# Add Q116393126: 8991, Q16180001, 'Tumbler'
# Q98821653: AttributeError for object_name: nan
# Add Q78610650: 812305, Q3305213, 'Hanging scroll'
# Add Q19920961: 482484, Q3305213, 'Painting'
# Add Q19925182: 10192, Q3305213, 'Painting, miniature'
# Add Q19923882: 11387, Q18761202, 'Watercolor'
# Add Q100706341: 107677, Q11284623, 'Afternoon dress'
# Add Q116444308: 625908, Q726826, 'Shabti, worker, Nauny'
# Add Q19924497: 15087, Q3305213, 'Painting, miniature'
# Add Q116372445: 1245, Q151771, 'Candlestick'
# Add Q29385498: 470298, Q12791, 'Sword'
# Add Q29385498: 470298, Q661140, 'Sword'
# Add Q116435579: 559723, Q46847, 'Ring'
# Add Q116371027: 2730, Q60310748, 'Cream pot'
# Add Q29385558: 501523, Q1823258, 'Soprano Recorder in B'
# Add Q78841073: 45718, Q3305213, 'Painting'
# Add Q116401263: 231913, Q11285759, 'Armchair'
# Add Q116440157: 567861, Q2442735, 'Scarab'
# Add Q116294202: 241062, Q860861, 'Head of a woman'
# Add Q116445567: 852563, Q11060274, 'Print'
# Add Q116399387: 200922, Q151771, 'Candlestick'
# Add Q116287505: 251561, Q2413314, 'Jug'
# Add Q116252614: 471047, Q12537, 'Corbel'
# Add Q98820708: 264178, Q125191, 'Photograph'
# Add Q29384364: 316442, Q5771190, 'Saltcellar'
# Add Q116246271: 591018, Q726826, 'Shabti, Henettawy C'
# Add Q98225261: 765285, Q3305213, 'Painting'
# Add Q116288761: 256067, Q2111434, 'Pendant'
# Add Q97581410: 302664, Q1757923, 'Carte-de-visite'
# Add Q116358283: 6691, Q3579073, 'Porringer'
# Add Q116248327: 450933, Q153988, 'Bowl'
# Add Q116311401: 190838, Q468402, 'Tile'
# Add Q96807108: 283782, Q125191, 'Photograph'
# Add Q116411389: 472835, Q499916, 'Brooch'
# Add Q19904855: 435668, Q3305213, 'Painting, predella panel'
# Add Q116274720: 562750, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q96800572: 268348, Q125191, 'Photograph'
# Add Q20201408: 469890, Q3305213, 'Roundel'
# Add Q116289552: 245761, Q673338, 'Alabastron'
# Add Q29385792: 544451, Q1066288, 'Statuette, standing boy, nude, Amenemhab, child'
# Add Q83562224: 39676, Q168456, 'Earring'
# Add Q20199404: 491916, Q3305213, 'Drawing'
# Add Q116409791: 451003, Q1264081, 'Incense burner'
# Add Q116370711: 3096, Q3917316, 'Decanter'
# Add Q116429134: 555254, Q131557, 'Amulet, Heart'
# Add Q96035516: 403906, Q1190417, 'Baseball card, photograph'
# Add Q116296620: 247925, Q579418, 'Lekythos'
# Add Q78808847: 51575, Q3305213, 'Handscroll'
# Add Q20178131: 13263, Q3305213, 'Drawing'
# Add Q116357300: 5869, Q132397, 'Pitcher'
# Add Q116373407: 405, Q833823, 'Beaker'
# Add Q116342384: 8024, Q2356786, 'Sugar Bowl'
# Add Q116344953: 8384, Q245005, 'Teapot'
# Add Q116372060: 1621, Q63495428, 'Side Chair'
# Add Q116432948: 558535, Q2442735, 'Scarab'
# Add Q98821666: 787918, Q125191, 'Photograph'
# Add Q6067946: 544232, Q3373936, 'Necklace, pectoral, Sithathoryunet-view-jewelry, Senwosret II'
# Add Q98821338: 270574, Q125191, 'Photograph'
# Add Q116276475: 468158, Q6806674, 'Pharmacy jar'
# Add Q116445448: 834048, Q722604, 'Reliquary'
# Add Q19924876: 13453, Q3305213, 'Painting'
# Add Q97581411: 302665, Q1757923, 'Carte-de-visite'
# Add Q78849899: 45202, Q3305213, 'Hanging scroll'
# Add Q19924726: 12890, Q3305213, 'Painting
# Frigate Presiden
# Frigate President and
# H.B.M. Endymion'
# WARNING: API error modification-failed: String should not start or end with whitespace nor include vertical whitespace or tabs: Painting Frigate Presiden Frigate President and H.B.M. Endymion
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[60], line 180
#     178 counter.start_time = perf_counter()
#     179 for item in pbar:
# --> 180     handle_item(item)
#     182 # Possible joblib speedup? Not happening
#     183 # Parallel(n_jobs=8, prefer="threads")(delayed(handle_item)(i) for i in generator)
#     184 counter.end_time = perf_counter()
#
# Cell In[60], line 136, in handle_item(item)
#     134         tqdm.write(f"  could not set object name to {object_name}")
#     135         return
# --> 136     statement.addQualifier(qualifier) # summary=u'Adding a qualifier.'
#     138     counter.statements += 1
#     140 counter.supplemented += 1
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/page/_wikibase.py:1837, in Claim.addQualifier(self, qualifier, **kwargs)
#    1834     raise ValueError(
#    1835         'The provided Claim instance is already used in an entity')
#    1836 if self.on_item is not None:
# -> 1837     data = self.on_item.repo.editQualifier(self, qualifier, **kwargs)
#    1838     self.on_item.latest_revision_id = data['pageinfo']['lastrevid']
#    1839     qualifier.on_item = self.on_item
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/site/_decorators.py:92, in need_right.<locals>.decorator.<locals>.callee(self, *args, **kwargs)
#      88 elif right is not None and not self.has_right(right):
#      89     raise UserRightsError('User "{}" does not have required '
#      90                           'user right "{}"'
#      91                           .format(self.user(), right))
# ---> 92 return fn(self, *args, **kwargs)
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/tools/_deprecate.py:479, in remove_last_args.<locals>.decorator.<locals>.wrapper(*__args, **__kw)
#     473     deprecated = [arg for arg in arg_names if arg in deprecated]
#     474     warn("The trailing arguments ('{}') of {} are deprecated. "
#     475          "The value(s) provided for '{}' have been dropped."
#     476          .format("', '".join(arg_names), name,
#     477                  "', '".join(deprecated)),
#     478          DeprecationWarning, depth)
# --> 479 return obj(*new_args, **new_kwargs)
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/site/_datasite.py:502, in DataSite.editQualifier(self, claim, qualifier, new, bot, summary)
#     499 params['property'] = qualifier.getID()
#     501 req = self.simple_request(**params)
# --> 502 return req.submit()
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/data/api/_requests.py:1094, in Request.submit(self)
#    1090     pywikibot.log('API Error: query=\n{}'
#    1091                   .format(pprint.pformat(param_repr)))
#    1092     pywikibot.log(f'           response=\n{result}')
# -> 1094     raise pywikibot.exceptions.APIError(**error)
#    1095 except TypeError:
#    1096     raise RuntimeError(result)
#
# APIError: modification-failed: String should not start or end with whitespace nor include vertical whitespace or tabs: Painting Frigate Presiden Frigate President and H.B.M. Endymion
# [messages: [{'name': 'wikibase-validator-illegal-string-chars', 'parameters': ['Painting\r\nFrigate Presiden\r\nFrigate President and\r\nH.B.M. Endymion'], 'html': {'*': 'String should not start or end with whitespace nor include vertical whitespace or tabs: Painting\r\nFrigate Presiden\r\nFrigate President and\r\nH.B.M. Endymion'}}];
#  servedby: mw1465;
#  help: See https://www.wikidata.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.]

# %%
print (type(item))
# Out:
# <class 'pywikibot.page._wikibase.ItemPage'>

# %%
# Supplement Wikidata items about Met's objects

# Script to supplement P31 statements for Met objects in Wikidata
# Start with getting all P31 statements
# Lookup the objectName in the Met database

# SPARQL query to list Met items without the P1932 set:
# https://w.wiki/6NiH

# Consider adding references
# Example: https://www.wikidata.org/wiki/Q18177495
# retrieved - 14 May 2015
# reference URL - http://www.metmuseum.org/collection/the-collection-online/search/435976

# Written to run on JupyterLab via https://paws.wmcloud.org

import pywikibot
import pandas as pd
from pywikibot import pagegenerators as pg
from pywikibot.data.sparql import SparqlQuery
import logging

from types import SimpleNamespace

import requests
import re
import numpy as np

from joblib import Parallel, delayed

from time import perf_counter
from tqdm.notebook import tqdm

def stringify_pywikibot_target(intarget) -> str:
    '''
    Take pywikibot target object and return a string version, or QID, or printed date object
    '''
    returnstring = ''
    # print ('Type', type(intarget))
    if isinstance(intarget, str):
        return intarget
    elif isinstance(intarget, pywikibot.page._wikibase.ItemPage):
        return intarget.id
    elif isinstance(intarget, pywikibot.WbTime):
        return str(intarget)
    return None

def retrieve_claim_propqual(item, inclaimprop, inclaimtarget=None, inqualprop=None, inqualvalue=None) -> list:
    ''' Retrieve an entire Wikidata claim if property/qualifier match 
        Only works with returning strings or items, which get returned as QIDs
    '''
    returnlist = []

    item.get(force=True)
    if not item.claims.get(inclaimprop):
        return returnlist
    for statement in item.claims[inclaimprop]:
        if not inclaimtarget:
            returnlist += [stringify_pywikibot_target(statement.target)]
        elif statement.target.id == inclaimtarget:
            # Process qualifiers, if they exist
            if inqualprop and inqualprop in statement.qualifiers:
                for qual in statement.qualifiers[inqualprop]: #iterate over all P1932
                    returnqualstring = stringify_pywikibot_target(qual.target)
                    if inqualvalue:
                        if inqualvalue == returnqualstring:
                            returnlist.append(returnqualstring)
                    else:
                        returnlist.append(returnqualstring)
            elif not inqualprop:
                # inclaimprop-inclaimtarget triple matched, but no qualifier specified
                # Then just return the inclaimtarget QID
                returnlist.append(stringify_pywikibot_target(statement.target))
    return returnlist

def metid_to_objectName (in_df, metid:str) -> str:
    '''Lookup met id (integer) in Dataframe loaded from Met CSV'''
    result = None
    foundrow = in_df.loc[in_df['Object ID'] == int(metid)]
    if not foundrow.empty:
        result = foundrow.at[foundrow.index[0],'Object Name']
    return result

def handle_item (item:pywikibot.page.ItemPage):
    # global counter
    
    object_name = None
    matched_qids = None

    counter.total += 1

    # tqdm.write(f"{item.id}")

    # Grab Met ID, which should return exactly one value
    metidlist    = retrieve_claim_propqual(item, 'P3634')
    instancelist = retrieve_claim_propqual(item, 'P31')
    if len(metidlist) != 1:
        tqdm.write(f"  {item.id}: Error, Met ID should be exactly one. Instead: {metidlist}")
        return

    metid = metidlist[0]  # Extract the lone Met ID

    # Look up object name, make sure to strip whitespace!
    object_name = metid_to_objectName (metdf, metid)
    if not object_name:
        tqdm.write(f"  {item.id}: Error, object name lookup with Met database returned empty")
        return
    try:
        object_name = object_name.strip()
    except AttributeError:
        tqdm.write(f"{item.id}: AttributeError for object_name: {object_name}")
        return

    # Grab Wikidata P31 claims
    item.claims.get('P31')
    for statement in item.claims.get('P31'):  # Get instance of

        if 'P1932' in statement.qualifiers:
            for qual in statement.qualifiers['P1932']: #iterate over all
                tqdm.write(f"{item.id}: Error, found unexpected P31|{statement.target.id}|P1932 claims: {qual}")
                # object_name = stringify_pywikibot_target(qual.target)
            continue

        # Output status message
        pbar.set_postfix_str(f"{item.id}: {metid}, should be {object_name}")

        tqdm.write(f"Add {item.id}: {metid}, {statement.target.id}, '{object_name}'")

        # Add qualifier with objectName string from Met
        qualifier = pywikibot.Claim(repo, 'P1932')
        try:
            qualifier.setTarget(object_name)
        except ValueError:
            tqdm.write(f"  could not set object name to {object_name}")
            return
        statement.addQualifier(qualifier) # summary=u'Adding a qualifier.'

        counter.statements += 1

    counter.supplemented += 1
    return

if __name__ == '__main__':

    # Init counters
    counterdict = {
        'total': 0,
        'supplemented': 0,
        'statements': 0,
        'start_time': 0,
        'end_time': 0
    }
    counter = SimpleNamespace(**counterdict)

    # LOG = "met-supplement-p31.log"
    # logging.basicConfig(filename=LOG, filemode="w", level=logging.DEBUG)

    # LOAD Met CSV
    if metdf.empty:
        metdf = pd.read_csv('MetObjects.csv',low_memory=False)

    # Do SPARQL query to grab all entries of P31->Q18593264 and no qualifier
    # Return QID, Met ID
    QUERY = '''
    SELECT ?item ?thing ?metid WHERE {
      # ?item wdt:P3634 ?metid .
      MINUS { ?item p:P31 [ps:P31 ?thing; pq:P1932 [] ] }
      # ?item wdt:P31 ?thing .
    } 
    '''

    # For SPARQL generator
    wikidata_site = pywikibot.Site("wikidata", "wikidata")
    repo = wikidata_site.data_repository()
    generator = pg.WikidataSPARQLPageGenerator(QUERY, site=wikidata_site)

    pbar = tqdm(generator) # For progress bar
    counter.start_time = perf_counter()
    for item in pbar:
        handle_item(item)

    # Possible joblib speedup? Not happening
    # Parallel(n_jobs=8, prefer="threads")(delayed(handle_item)(i) for i in generator)
    counter.end_time = perf_counter()

    # Output final report
    tqdm.write(f"Finished")
    tqdm.write(f"Time elapsed: {counter.end_time-counter.start_time} secs")
    tqdm.write(f"Items examined: {counter.total}")
    tqdm.write(f"Items supplemented: {counter.supplemented}")
    tqdm.write(f"Statements added: {counter.statements}")
# Out:
# 0it [00:00, ?it/s]
#   Q20172025: Error, object name lookup with Met database returned empty
# Q97013416: AttributeError for object_name: nan
# Add Q96184317: 364154, Q11060274, 'Print'
# Add Q78619827: 670942, Q3305213, 'Hanging scroll'
# Add Q116244673: 451492, Q6916434, 'Mosque lamp'
# Add Q116410533: 468598, Q1264081, 'Censer'
# Add Q104413027: 359882, Q11060274, 'Print'
# Add Q116329992: 14495, Q191851, 'Vase'
# Add Q116410564: 469930, Q1066288, 'Statuette'
# Add Q96802968: 271932, Q125191, 'Photograph'
# Add Q19925198: 12703, Q3305213, 'Painting, miniature'
# Add Q116398959: 197569, Q245005, 'Teapot'
# Add Q116352455: 6069, Q57216, 'Plate'
# Add Q98821665: 787917, Q125191, 'Photograph'
# Add Q116371127: 2656, Q60310748, 'Cream pot'
# Add Q116313540: 49694, Q4364339, 'Plaque'
# Add Q116235479: 490684, Q132397, 'Pitcher'
# Add Q78683300: 75079, Q3305213, 'Folio'
# Add Q116445313: 823315, Q81727, 'Cup'
# Add Q104413108: 751510, Q2568536, 'Cradleboard'
# Add Q116273230: 454675, Q1348059, 'Panel'
# Add Q116364971: 6154, Q57216, 'Plate'
# Add Q116256776: 550552, Q2442735, 'Scarab'
# Add Q116392381: 6018, Q57216, 'Plate'
# Add Q116364886: 6163, Q57216, 'Plate'
# Add Q105809560: 45746, Q193220, 'Folding fan mounted as an album leaf'
# Add Q20173801: 14429, Q3305213, 'Painting, miniature'
# Add Q96183127: 291591, Q125191, 'Photogram'
# Add Q96357722: 491411, Q11060274, 'Print'
# Add Q116240678: 206412, Q10672725, 'Snuffbox'
# Add Q116370822: 2948, Q18349459, 'Cup plate'
# Add Q116409193: 434360, Q1190417, 'Baseball card, print'
# Add Q116351789: 7012, Q5771190, 'Salt'
# Add Q83560054: 2295, Q153988, 'Bowl'
# Add Q19912055: 437255, Q3305213, 'Painting'
# Add Q83561985: 19525, Q11285759, 'Armchair'
# Add Q116342581: 9412, Q191851, 'Vase'
# Add Q96586229: 708988, Q125191, 'Photograph'
# Add Q78747500: 54737, Q3305213, 'Album leaf'
# Add Q19912292: 436760, Q3305213, 'Painting'
# Add Q116306899: 210780, Q4364339, 'Plaque'
# Add Q19913347: 440375, Q3305213, 'Painting'
# Add Q116431851: 556294, Q2442735, 'Scarab'
# Add Q29384545: 327830, Q3305213, 'Painted panel'
# Add Q116402362: 247493, Q579418, 'Lekythos'
# Add Q116373179: 610, Q18696213, 'Flask'
# Add Q78913615: 37859, Q3305213, 'Folio'
# Add Q97012779: 291776, Q125191, 'Daguerreotype'
# Add Q116313731: 49398, Q987767, 'Wine container'
# Add Q116392809: 7638, Q57216, 'Soup dish'
# Add Q116392809: 7638, Q17379525, 'Soup dish'
# Add Q116431662: 556171, Q1123756, 'Cylinder seal'
# Add Q20194076: 486182, Q3305213, 'Painting'
# Add Q116393619: 19845, Q191851, 'Vase'
# Add Q78850038: 45188, Q3305213, 'Hanging scroll'
# Add Q96357612: 364497, Q11060274, 'Print'
# Add Q116370536: 3335, Q746549, 'Dish'
# Add Q116243506: 460734, Q18451251, 'Goblet'
# Add Q19906262: 437520, Q3305213, 'Painting'
# Add Q97853182: 788302, Q11060274, 'Print'
# Add Q20200346: 488533, Q3305213, 'Drawing'
# Add Q116374120: 192728, Q17489160, 'Bust'
# Add Q116430941: 555579, Q131557, 'Amulet, frog'
# Add Q19911768: 437844, Q3305213, 'Painting'
# Add Q116431977: 556391, Q2442735, 'Scarab'
# Add Q19913198: 435986, Q3305213, 'Painting'
# Add Q116242938: 460884, Q18451251, 'Goblet'
# Add Q20199801: 483681, Q3305213, 'Drawing'
# Add Q116242761: 446204, Q153988, 'Bowl'
# Add Q116437794: 561011, Q2442735, 'Scarab'
# Add Q116412971: 501225, Q7295963, 'Rattle'
# Add Q19920891: 486406, Q3305213, 'Painting'
# Add Q116245691: 460218, Q746549, 'Dish'
# Add Q20200688: 493544, Q3305213, 'Print'
# Add Q20193708: 483758, Q17126091, 'Textile sample'
# Add Q116371318: 2508, Q2356786, 'Sugar bowl'
# Add Q20185492: 460332, Q3305213, 'Frame'
# Add Q20188372: 460116, Q3305213, 'Drawing'
# Add Q19917533: 486008, Q3305213, 'Painting'
# Add Q20177099: 15251, Q3305213, 'Painting, miniature'
# Add Q104412971: 4470, Q1207302, 'Chocolate jar'
# Add Q116432212: 556579, Q80228, 'Bottle'
# Add Q19914390: 481657, Q3305213, 'Painting'
# Add Q68352163: 81142, Q1034198, 'Cape'
# Add Q116309865: 207320, Q11285759, 'Armchair'
# Add Q20200080: 483409, Q860861, 'Sculpture'
# Add Q97731204: 337324, Q11060274, 'Print'
# Add Q116361616: 6552, Q3391771, 'Platter'
# Add Q116291597: 245469, Q673338, 'Alabastron'
# Add Q116288996: 253817, Q1665351, 'Intaglio'
# Add Q97768184: 679176, Q11060274, 'Print'
# Add Q116374203: 72393, Q29527347, 'Figure'
# Add Q96054119: 812821, Q11060274, 'Print'
# Add Q116280457: 546989, Q2442735, 'Scarab'
# Add Q116282362: 324126, Q860861, 'Sculpture'
# Add Q20190087: 486585, Q3305213, 'Print'
# Add Q116444768: 719111, Q189299, 'Necklace'
# Add Q96800641: 269129, Q125191, 'Photograph'
# Add Q116439213: 562753, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q102304806: 387811, Q18219090, 'Print'
# Add Q116406659: 268823, Q125191, 'Photograph'
# Add Q116244266: 460567, Q153988, 'Bowl'
# Add Q116392970: 8865, Q2569925, 'Trivet'
# Add Q96756857: 654090, Q1064538, 'Quilt'
# WARNING: API error mwoauth-invalid-authorization: The authorization headers in your request are not valid: Nonce already used: 21654220307546377761677402127
# ERROR: Retrying failed OAuth authentication for wikidata:wikidata: The authorization headers in your request are not valid: Nonce already used: 21654220307546377761677402127
# Add Q78712102: 73299, Q3305213, 'Handscrolls'
# Add Q116281220: 461283, Q2537127, 'Plaquette'
# Add Q20200241: 482449, Q3305213, 'Drawing'
# Add Q19923564: 486720, Q3305213, 'Drawing'
# Add Q116434136: 559301, Q1422576, 'Model dish, Perneb'
# Add Q116289741: 248393, Q860861, 'Head of a woman'
# Add Q116295944: 248777, Q1066288, 'Statuette of an actor'
# Add Q116366608: 4671, Q193358, 'Ladle'
# Add Q116311602: 188779, Q1066288, 'Statuette'
# Add Q98821644: 716313, Q125191, 'Photograph'
# Add Q116390629: 1367, Q151771, 'Candlestick'
# Add Q97852593: 775514, Q11060274, 'Print'
# Add Q116242861: 452027, Q860861, 'Figural vessel'
# Add Q116246220: 591035, Q726826, 'Shabti, Henettawy C'
# Add Q20194803: 488695, Q3305213, 'Painting'
# Add Q20197879: 491747, Q22075301, 'Textile piece'
# Add Q20197879: 491747, Q29639251, 'Textile piece'
# Add Q116306994: 206455, Q57216, 'Plate'
# Add Q20183472: 459108, Q3305213, 'Painting'
# Add Q78827925: 49131, Q3305213, 'Album'
# Add Q78827925: 49131, Q1173065, 'Album'
# Add Q19924960: 18113, Q3305213, 'Painting'
# Add Q98821630: 668005, Q125191, 'Photograph'
# Add Q116248174: 544246, Q148449, 'Magic wand'
# Add Q116289954: 254902, Q1539580, 'Pelike'
# Add Q116306807: 208577, Q3775662, 'Inkstand'
# Add Q116291469: 253660, Q28512, 'Cameo'
# Add Q19912344: 436416, Q3305213, 'Painting'
# Add Q116432109: 556487, Q2442735, 'Scarab'
# Add Q116406081: 255661, Q673338, 'Alabastron'
# Add Q116438270: 561255, Q11086567, 'Jar Fragment, Siptah'
# Add Q97775782: 756628, Q11060274, 'Print'
# Add Q97853184: 788303, Q11060274, 'Print'
# Add Q99807189: 87044, Q249975, 'Robe à la Française'
# Add Q116434036: 559285, Q1422576, 'Model dish, Perneb'
# Q29388338: AttributeError for object_name: nan
# Add Q116275472: 481002, Q81727, 'Cup'
# Add Q116371500: 2359, Q746549, 'Dish'
# Add Q116289896: 242015, Q179700, 'Statue of a priest'
# Add Q98820631: 263577, Q125191, 'Photograph'
# Add Q96586273: 769225, Q125191, 'Photograph'
# Add Q116409274: 446110, Q11086567, 'Fragment'
# Add Q116410504: 466365, Q193893, 'Capital'
# Add Q19923965: 12985, Q3305213, 'Painting, miniature'
# Add Q116344614: 7934, Q2356786, 'Sugar bowl'
# Add Q116390622: 1361, Q151771, 'Candlestick'
# Add Q19925419: 13006, Q3305213, 'Painting'
# Add Q97012672: 286330, Q125191, 'Photograph'
# Add Q100348239: 156947, Q8251241, 'Bootees'
# Add Q116243718: 545565, Q1066288, 'Figurine, Hippopotamus'
# Add Q116297184: 244074, Q1066288, 'Statuette of a woman'
# Add Q116417762: 550479, Q11086567, 'Foundation Deposit Plaque, Calf's Head'
# Add Q116439166: 562712, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116246272: 591017, Q726826, 'Shabti, Henettawy C'
# Add Q20200650: 488170, Q3575260, 'Pendant'
# Add Q20178086: 12736, Q18761202, 'Watercolor'
# Add Q116240852: 75405, Q722604, 'Reliquary'
# Add Q97772141: 754095, Q11060274, 'Print'
# Add Q116391270: 2471, Q188075, 'Box'
# Add Q98821553: 294427, Q125191, 'Photograph'
# Add Q78870319: 39657, Q3305213, 'Handscroll'
# Add Q29385801: 544501, Q178401, 'Amphora, ibex, blue-painted ware'
# Add Q116370389: 3529, Q1348059, 'Panel'
# Add Q116251924: 471374, Q1348059, 'Panel'
# Add Q116433608: 558933, Q95975776, 'Coffin Inlay'
# Add Q116307285: 205010, Q95921197, 'Salver'
# Add Q78233568: 36932, Q11060274, 'Print'
# Add Q100706414: 108052, Q200539, 'Dress'
# Add Q116282676: 258494, Q746549, 'Dish'
# Add Q116373440: 383, Q833823, 'Beaker'
# Add Q83562080: 38174, Q179700, 'Statue'
# Add Q83562310: 42718, Q29527347, 'Figure'
# Add Q116280655: 452519, Q208440, 'Chess piece'
# Add Q109567907: 285906, Q125191, 'Photograph'
# Add Q97769700: 712355, Q11060274, 'Print'
# Add Q97852646: 786241, Q11060274, 'Print'
# Add Q116273710: 464194, Q4364339, 'Plaque'
# Add Q116242700: 445692, Q28823, 'Fragment'
# Add Q116242700: 445692, Q11086567, 'Fragment'
# Add Q98225267: 811007, Q2741056, 'Cabinet'
# Add Q116242654: 447365, Q80228, 'Bottle'
# Add Q20191730: 491601, Q210064, 'Lamps'
# Add Q116310500: 195949, Q833823, 'Beaker'
# Add Q116417271: 550404, Q2442735, 'Scarab'
# Add Q19920775: 484540, Q3305213, 'Drawing'
# Add Q20201852: 473889, Q3305213, 'Statuette'
# Add Q116243085: 556962, Q11086567, 'Tile fragment'
# Add Q116243085: 556962, Q468402, 'Tile fragment'
# Add Q116273319: 469000, Q168456, 'Earring'
# Add Q116256244: 470792, Q193893, 'Capital'
# Add Q116290125: 248337, Q860861, 'Head of a woman'
# Add Q116333013: 7779, Q81895, 'Spoon'
# Add Q78913843: 37857, Q3305213, 'Folio'
# Add Q20175539: 10337, Q3305213, 'Painting'
# Add Q97850000: 757251, Q11060274, 'Print'
# Add Q116373439: 381, Q833823, 'Beaker'
# Add Q116250548: 38269, Q245117, 'Relief fragment'
# Add Q96185300: 544637, Q3305213, 'Facsimile, Rekhmire (TT 100), leather work, sandals'
# Add Q116289212: 250070, Q833823, 'Beaker'
# Add Q116396610: 53560, Q1317634, 'Cauldron'
# Add Q97768175: 678297, Q11060274, 'Print'
# Add Q96585920: 488055, Q860861, 'Sculpture'
# Add Q19914308: 439385, Q3305213, 'Painting'
# Add Q116374545: 38582, Q178743, 'Stele'
# Add Q116432294: 556655, Q2366864, 'Pot'
# Add Q100706419: 108079, Q200539, 'Dress'
# Add Q116413942: 545421, Q131557, 'Amulet, Heart'
# Add Q19913109: 437581, Q3305213, 'Painting, drawing'
# Add Q20199259: 490764, Q11060274, 'Print'
# Add Q116392515: 6406, Q57216, 'Plate'
# Add Q78883071: 37892, Q3305213, 'Folio'
# Add Q116280983: 467493, Q151771, 'Candlestick'
# Add Q96053862: 418781, Q1190417, 'Photograph, baseball card'
# Add Q116398953: 197565, Q245005, 'Teapot'
# Add Q96586188: 708768, Q125191, 'Photograph'
# Add Q116295379: 247205, Q1350279, 'Pyxis with lid'
# Add Q116295379: 247205, Q2488579, 'Pyxis with lid'
# Add Q116296807: 244159, Q330946, 'Dagger blade'
# Q98821690: AttributeError for object_name: nan
# Add Q116306713: 234099, Q548275, 'Candelabra'
# Add Q116246230: 591032, Q726826, 'Shabti, Henettawy C'
# Add Q19922175: 488826, Q3305213, 'Painting'
# Add Q97769695: 712333, Q11060274, 'Print'
# Add Q20190038: 486755, Q3305213, 'Painting'
# Add Q78620454: 670930, Q3305213, 'Hanging scroll'
# Add Q20193809: 485022, Q3305213, 'Painting'
# Add Q116374282: 44893, Q179700, 'Statue'
# Add Q98821372: 282762, Q125191, 'Transparency'
# Add Q116310690: 194295, Q57216, 'Plate'
# Add Q19917739: 632922, Q3305213, 'Painting'
# Add Q116371970: 1759, Q63495428, 'Side Chair'
# Add Q61040922: 49936, Q18219090, 'Woodblock print'
# Add Q78824136: 49255, Q3305213, 'Folding fan'
# Add Q96183809: 336669, Q11060274, 'Print'
# Add Q116343796: 7951, Q2356786, 'Sugar Bowl'
# Add Q19917829: 484891, Q3305213, 'Painting'
# Add Q116442925: 575508, Q1053956, 'Bead'
# Add Q116314153: 42172, Q987767, 'Wine vessel'
# Add Q19914098: 436298, Q3305213, 'Painting, miniature'
# Add Q116290171: 246599, Q755706, 'Kantharos'
# Add Q116411469: 473301, Q4364339, 'Plaque'
# Add Q20175198: 11324, Q3305213, 'Painting'
# Add Q116240966: 23143, Q858236, 'Breastplate'
# Add Q116326590: 20601, Q2106696, 'Dressing table'
# Add Q116436334: 560144, Q2442735, 'Scaraboid'
# Add Q19911654: 440393, Q3305213, 'Painting'
# Add Q98821589: 299327, Q125191, 'Photograph'
# Add Q19912018: 437049, Q3305213, 'Painting'
# Add Q116310374: 204640, Q11285759, 'Armchair'
# Add Q116442770: 573714, Q2442735, 'Scaraboid'
# Add Q116242123: 252963, Q579418, 'Lekythos'
# Add Q96357702: 491318, Q11060274, 'Print'
# Add Q19913470: 438551, Q3305213, 'Painting'
# Add Q19912050: 437012, Q3305213, 'Painting, cassone panel'
# Add Q116298482: 665567, Q132397, 'Pitcher'
# Add Q20197746: 487929, Q3305213, 'Painting'
# Add Q116275234: 562064, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q19917796: 632952, Q3305213, 'Painting'
# Add Q116392919: 8792, Q613972, 'Tray'
# Add Q116372440: 1255, Q151771, 'Candlestick'
# Add Q116240829: 191329, Q860861, 'Group'
# Add Q116240829: 191329, Q16887380, 'Group'
# Add Q116433030: 558619, Q2442735, 'Scarab'
# Add Q116247819: 471886, Q1348059, 'Panel'
# Add Q78840963: 45721, Q3305213, 'Hanging scroll'
# Add Q116374480: 38949, Q29527347, 'Figure'
# Add Q20190867: 486007, Q3305213, 'Painting'
# Add Q116398412: 196467, Q1066288, 'Statuette'
# Add Q98224650: 19821, Q46847, 'Ring'
# Add Q116378818: 9418, Q191851, 'Vase'
#   Q116726442: Error, object name lookup with Met database returned empty
# Add Q19918903: 486894, Q3305213, 'Painting'
# Add Q20178209: 16891, Q18761202, 'Watercolor'
# Add Q20178209: 16891, Q21281546, 'Watercolor'
# Add Q98821539: 291976, Q125191, 'Photographs'
# Add Q20197984: 493904, Q3305213, 'Sculpture'
# Add Q20198486: 482173, Q15026, 'Side chair'
# Add Q19912871: 437848, Q3305213, 'Painting'
# Add Q116431822: 556274, Q2442735, 'Scarab'
# Add Q116434624: 559464, Q2442735, 'Scarab'
# Add Q19924007: 21473, Q3305213, 'Painting, miniature'
# Add Q98823247: 267677, Q125191, 'Photograph'
# Add Q116256116: 472189, Q208454, 'Abacus'
# Add Q116314112: 44754, Q153988, 'Bowl'
# Add Q116280122: 559619, Q2442735, 'Scarab'
# Add Q116272638: 550311, Q2442735, 'Scarab, Ramesses II'
# Add Q78697342: 75008, Q3305213, 'Folio'
# Add Q97853976: 811880, Q11060274, 'Print'
# Add Q19914244: 436866, Q3305213, 'Painting'
# Add Q116314271: 44610, Q79137673, 'Screen'
# Add Q116308116: 199852, Q131647, 'Medal'
# Add Q19922840: 486541, Q3305213, 'Drawing'
# Add Q20189457: 486011, Q3305213, 'Painting'
# Add Q83562738: 73150, Q29527347, 'Figure'
# Add Q19912969: 436645, Q3305213, 'Painting'
# Add Q99810114: 168950, Q22676, 'Shoes'
# Add Q29384248: 310552, Q1264081, 'Vessel'
# Add Q116441040: 568790, Q11086567, 'Vase fragment'
# Add Q20201523: 471115, Q3305213, 'Roundel'
# Add Q116313235: 52990, Q188075, 'Box'
# Add Q96586246: 710774, Q11060274, 'Print'
# Add Q97854179: 812000, Q11060274, 'Print'
# Add Q116418559: 550735, Q726826, 'Shabti'
# Add Q116439157: 562702, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116332467: 9942, Q18451251, 'Goblet'
# Add Q116406059: 255646, Q838312, 'Pin'
# Add Q20201712: 471871, Q3305213, 'Lancet heads'
# Add Q96149039: 544161, Q1066288, 'Figurine, Hippopotamus'
# Add Q98823330: 282514, Q125191, 'Photograph'
# Add Q116282336: 322349, Q41207, 'Coin'
# Add Q98823787: 291401, Q125191, 'Photograph'
# Add Q116236438: 467760, Q96097957, 'Coffret'
# Add Q116289574: 249399, Q81727, 'Cup'
# Add Q116343422: 7959, Q2356786, 'Sugar bowl'
# Add Q97580141: 283197, Q125191, 'Photograph'
# Add Q116328487: 16738, Q2990690, 'Compote'
# Add Q116402911: 251166, Q1066288, 'Statuette of a woman'
# Add Q116377488: 38181, Q29527347, 'Figure'
# Add Q116366226: 4786, Q14748, 'Library table'
# Add Q116297203: 246911, Q1138737, 'Lamp'
# Add Q116444842: 742380, Q189299, 'Necklace'
# Add Q78759717: 53405, Q3305213, 'Pair of hanging scrolls'
# Add Q19930492: 11145, Q3305213, 'Painting'
# Add Q78841516: 45711, Q3305213, 'Painting'
# Add Q116372843: 859, Q153988, 'Bowl'
# Add Q19913092: 438375, Q3305213, 'Painting'
# Add Q20188139: 460799, Q3305213, 'Leaf from a book of hours (?)'
# Add Q97579778: 268098, Q125191, 'Photograph'
# Add Q116272793: 455024, Q48498, 'Illustrated manuscript'
# Add Q19924747: 11107, Q3305213, 'Painting'
# Add Q116402475: 248796, Q579418, 'Lekythos'
# Add Q97012933: 291812, Q125191, 'Daguerreotype'
# Add Q19923822: 15013, Q3305213, 'Painting, miniature'
# Add Q20201637: 471073, Q3305213, 'Roundel'
# Add Q100706478: 168293, Q110304, 'Top hat'
# Add Q116245655: 460225, Q57216, 'Plate'
# Add Q116249865: 465236, Q499916, 'Brooch'
# Add Q116298430: 669093, Q1207302, 'Jar'
# Add Q116393690: 19918, Q191851, 'Vase'
# Add Q20200297: 484869, Q3305213, 'Drawing'
# Add Q97853036: 788027, Q11060274, 'Print'
# Add Q116274708: 548753, Q201097, 'Basket'
# Add Q116275207: 562062, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116274093: 464086, Q29382731, 'Garniture or mounting'
# Add Q116442033: 569629, Q2442735, 'Scarab'
# Add Q59769601: 55208, Q18219090, 'Print'
# Add Q19919352: 483199, Q3305213, 'Painting'
# Add Q116396220: 49353, Q29527347, 'Figure'
# Add Q116328504: 15862, Q191851, 'Vase'
# Add Q96035615: 403958, Q1190417, 'Baseball card, photograph'
# Add Q116310609: 199478, Q22075301, 'Length'
# Add Q116370435: 3458, Q6806674, 'Apothecary jar'
# Add Q78997019: 36035, Q3305213, 'Handscroll'
# Add Q96053874: 665862, Q1190417, 'Print baseball card'
# Add Q116371386: 2448, Q153988, 'Bowl'
# Add Q116444541: 700205, Q93184, 'Drawing'
# Add Q96586063: 491426, Q11060274, 'Print'
# Add Q116393292: 9955, Q1531435, 'Wine glass'
# Add Q116440178: 567880, Q4364339, 'Plaque'
# Add Q116399336: 199694, Q245005, 'Teapot'
# Add Q19912584: 437197, Q3305213, 'Painting'
# Add Q116252470: 471133, Q35473, 'Window'
# Add Q18708810: 240553, Q41971267, 'Krater, four-handled with lid'
# Add Q18708810: 240553, Q476968, 'Krater, four-handled with lid'
# Add Q116308195: 203090, Q29527347, 'Figure'
# Add Q19924842: 10774, Q3305213, 'Painting, miniature'
# Add Q116438735: 562272, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116289055: 246658, Q960844, 'Cinerary urn with lid'
# Add Q116289055: 246658, Q2488579, 'Cinerary urn with lid'
# Add Q20199616: 481950, Q3305213, 'Painting'
# Add Q96794921: 268312, Q125191, 'Photograph'
# Add Q116393714: 19942, Q191851, 'Vase'
# Add Q29385342: 463188, Q184296, 'Tapestry'
# Add Q116276267: 468219, Q29401129, 'Statue head'
# Add Q19917653: 484828, Q3305213, 'Painting'
# Add Q97731174: 294333, Q125191, 'Photograph'
# Add Q116409203: 444712, Q57216, 'Plate'
# Add Q97788452: 811266, Q11060274, 'Print'
# Add Q116314102: 44773, Q1317634, 'Cauldron'
# Add Q96035417: 403787, Q1190417, 'Baseball card, photograph'
# Add Q97581412: 302666, Q1757923, 'Carte-de-visite'
# Add Q19913381: 435957, Q3305213, 'Painting'
# Add Q116251857: 464548, Q115488, 'Medallion'
# Add Q100709858: 107687, Q200539, 'Dress'
# Add Q98821469: 289410, Q125191, 'Photograph'
# Add Q97013242: 702990, Q125191, 'Photograph'
#   Q99809843: Error, object name lookup with Met database returned empty
# Add Q116325504: 17503, Q1207302, 'Jar'
# Add Q116247640: 552414, Q2442735, 'Scarab'
# Add Q78835367: 48900, Q3305213, 'Hanging scroll'
# Add Q116445377: 825833, Q188075, 'Box'
# Add Q116235385: 545420, Q131557, 'Amulet, Heart'
# Add Q116309859: 206698, Q1066288, 'Statuette'
# Add Q116393108: 8965, Q2569925, 'Trivet'
# Add Q116430028: 555388, Q131557, 'Amulet'
# Add Q20201516: 471114, Q3305213, 'Roundel'
# Add Q20199355: 493415, Q3305213, 'Print'
# Add Q19914340: 490751, Q3305213, 'Painting'
# Add Q97732266: 389077, Q11060274, 'Print'
# Add Q116374349: 39851, Q245117, 'Relief'
# Add Q116308182: 202429, Q131647, 'Medal'
# Add Q116385786: 670002, Q468402, 'Tile'
# Add Q97013422: 821166, Q125191, 'Daguerreotype'
# Add Q116363858: 5612, Q57216, 'Plate'
# Add Q116441698: 569420, Q2442735, 'Scarab'
# Add Q116242716: 446236, Q2111434, 'Pendant'
# Add Q104413006: 20498, Q63495428, 'Side chair'
# Add Q20176921: 17515, Q3305213, 'Painting, miniature'
# Add Q116398254: 196321, Q468402, 'Tile'
# Add Q116335463: 7681, Q87718085, 'Soup plate'
# Add Q78761149: 53181, Q3305213, 'Hanging scroll'
# Add Q116394074: 21790, Q613972, 'Tray'
# Add Q116274137: 453574, Q35473, 'Window'
# Add Q116372311: 1390, Q151771, 'Candlestick'
# Add Q116393559: 18235, Q81895, 'Spoon'
# Add Q116240645: 209018, Q548275, 'Candelabra'
# Add Q116411369: 472765, Q65769142, 'Stamp'
# Add Q20200755: 489690, Q3305213, 'Drawing'
# Add Q97010008: 271912, Q125191, 'Photograph'
# Add Q116370236: 3707, Q18696213, 'Flask'
# Add Q100706556: 174738, Q535576, 'Bustle'
# Add Q29385050: 447086, Q1406758, 'Finial'
# Add Q116359219: 5812, Q60310748, 'Cream pot'
# Add Q19925713: 15987, Q3305213, 'Painting, miniature'
# Add Q19918589: 485842, Q3305213, 'Painting'
#   Q99809838: Error, object name lookup with Met database returned empty
# Add Q116246121: 460143, Q1888893, 'Albarello'
# Add Q96035708: 404336, Q1190417, 'Baseball card, photograph'
# Add Q116404666: 253659, Q2442735, 'Scaraboid'
# Add Q116311065: 232292, Q2148216, 'Upholstery panel'
# Add Q116341886: 8069, Q14748, 'Table'
# Add Q116280045: 477239, Q499916, 'Brooch'
# Add Q19921297: 488034, Q3305213, 'Painting'
# Add Q116444529: 698344, Q189299, 'Necklace'
# Add Q105693296: 825509, Q11060274, 'Print'
# Add Q116437626: 560982, Q1566584, 'Hair pin'
# Add Q78611922: 761570, Q3305213, 'Painting'
# Add Q116395494: 42219, Q746549, 'Dish'
# Add Q78875690: 38022, Q3305213, 'Painting'
# Add Q116274353: 487559, Q191851, 'Vase'
# Add Q29385655: 503670, Q281460, 'Pipe Organ'
# Add Q116314292: 47429, Q191851, 'Vase'
# Add Q19913650: 436345, Q3305213, 'Painting'
# Add Q97788823: 811536, Q11060274, 'Print'
# Add Q116276799: 467836, Q1348059, 'Panel'
# Add Q116287979: 255297, Q668349, 'Kylix'
# Add Q19924031: 17054, Q93184, 'Drawing'
# Add Q20201521: 471094, Q3305213, 'Roundel'
# Add Q78853099: 42343, Q3305213, 'Hanging scroll'
# Add Q116374455: 39016, Q1066288, 'Figurine'
# Add Q116332970: 8218, Q3446398, 'Tankard'
# Add Q116360485: 5777, Q132397, 'Pitcher'
# Add Q116289203: 248504, Q57216, 'Plate'
# Add Q116314328: 42059, Q581776, 'Boulder'
# Add Q19912338: 436456, Q3305213, 'Painting'
# Add Q98821034: 266453, Q57207952, 'Polaroid'
# Add Q116419569: 552736, Q191851, 'Vase'
# Add Q96278396: 55271, Q18219090, 'Print'
# Add Q97772136: 754011, Q11060274, 'Print'
# Add Q78706904: 74752, Q3305213, 'Painting'
# Add Q116289924: 246589, Q11086465, 'Neck-amphora'
# Add Q116351678: 7036, Q5771190, 'Salt'
# Add Q78617689: 671012, Q3305213, 'Hanging scroll'
# Add Q19925328: 12925, Q3305213, 'Painting'
# Add Q20187969: 458982, Q3305213, 'Painting'
# Add Q19924764: 17803, Q3305213, 'Painting'
# Add Q78839518: 45760, Q3305213, 'Hanging scroll'
# Add Q116370221: 3722, Q18696213, 'Flask'
# Add Q19911675: 437276, Q3305213, 'Painting'
# Add Q29383198: 24953, Q12791, 'Short sword (Yatagan)'
# Add Q116365619: 5432, Q821952, 'Whale oil lamp'
# Add Q96053445: 404518, Q1190417, 'Baseball card, photograph'
# Add Q98821656: 787904, Q125191, 'Photograph'
# Add Q116317047: 39623, Q238231, 'Disk'
# Add Q98225292: 840446, Q5078274, 'Sketch'
# Add Q68352246: 83259, Q2144456, 'Evening dress'
# Add Q68352246: 83259, Q1908472, 'Evening dress'
#   Q18338439: Error, Met ID should be exactly one. Instead: ['391070', '391069']
# Add Q116252527: 464897, Q499916, 'Brooch'
# Add Q116373167: 624, Q80228, 'Bottle'
# Add Q116438995: 562530, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116291785: 242604, Q168456, 'Earring'
# Add Q116289171: 249411, Q153988, 'Bowl'
# Add Q98821439: 285454, Q125191, 'Photograph'
# Add Q20198338: 482024, Q3305213, 'Painting'
# Add Q116275048: 562154, Q11086567, 'Relief fragment, tomb of Meketre'
#   Q19913265: Error, object name lookup with Met database returned empty
# Add Q78883012: 37893, Q3305213, 'Folio'
# Add Q116290118: 254881, Q11086465, 'Neck-amphora'
# Add Q100347845: 156329, Q876824, 'Wedding Slippers'
# Add Q98820745: 265169, Q125191, 'Photograph'
# Add Q116411586: 478984, Q46847, 'Ring'
# Add Q116291457: 245507, Q1066288, 'Statuette of a woman'
# Add Q116295806: 240718, Q2413314, 'Jug'
# Add Q19917459: 488768, Q3305213, 'Painting'
# Add Q116390141: 228, Q11285759, 'Armchair'
# Add Q83559882: 13148, Q17489160, 'Bust'
# Add Q116348666: 7862, Q81727, 'Cup'
# Add Q116389741: 666573, Q1264081, 'Incense burner'
# Add Q96794966: 268334, Q125191, 'Photograph'
# Add Q116282439: 323827, Q66018222, 'Cuneiform tablet'
# Add Q116374548: 38577, Q4817, 'Column'
# Add Q116371059: 2707, Q27667572, 'Cream pitcher'
# Add Q19919860: 490220, Q3305213, 'Painting'
# Add Q68352092: 81101, Q2144456, 'Evening dress'
# Add Q68352092: 81101, Q1908472, 'Evening dress'
# Add Q116348599: 9266, Q191851, 'Vase'
# Add Q3842520: 435614, Q3305213, 'Painting'
# Add Q116436613: 560573, Q28823, 'Linen fragment'
# Add Q116436613: 560573, Q11086567, 'Linen fragment'
# Add Q20201876: 472326, Q3305213, 'Tracery light'
# Add Q20178413: 11378, Q93184, 'Watercolor'
# Add Q19924635: 11055, Q3305213, 'Painting'
# Add Q97327122: 73214, Q1352349, 'Temple model'
# Add Q116297123: 240136, Q2413314, 'Jug'
# Add Q116370583: 3283, Q746549, 'Dish'
# Add Q19913103: 437232, Q3305213, 'Painting'
# Add Q116273175: 469063, Q168456, 'Earring'
# Add Q19924604: 11540, Q3305213, 'Watercolor'
# Add Q116431825: 556277, Q2442735, 'Scarab'
# Add Q98820256: 259857, Q125191, 'Photograph'
# Add Q96584906: 259651, Q125191, 'Photograph'
# Add Q116273637: 464227, Q506002, 'Crozier head'
# Add Q20199201: 486727, Q3305213, 'Print'
# Add Q20197351: 489407, Q3305213, 'Painting'
# Add Q116242772: 447008, Q1264081, 'Incense burner'
# Add Q116396812: 60646, Q191851, 'Vase'
# Add Q20195866: 485034, Q3305213, 'Painting'
# Add Q78919705: 36155, Q3305213, 'Album leaf'
# Add Q20167013: 436562, Q3305213, 'Painting, predella panel'
# Add Q116431976: 556390, Q2442735, 'Scarab'
# Add Q97581173: 294464, Q125191, 'Photograph'
# Add Q29385638: 503546, Q202027, 'Cornet à Pistons in B-flat'
# Add Q116273979: 468717, Q29401129, 'Statue head'
# Add Q116342388: 8022, Q3276479, 'Tongs'
# Add Q96358067: 653746, Q93184, 'Drawing'
# Add Q116424288: 553898, Q2442735, 'Scarab, Amenhotep II'
# Add Q100145704: 106619, Q635784, 'Ball gown'
# Add Q20171727: 13040, Q3305213, 'Painting, miniature'
# Add Q96748776: 123868, Q200539, 'Evening dress'
# Add Q116439087: 562609, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116365558: 5441, Q821952, 'Whale oil lamp'
# Add Q116247044: 465797, Q499916, 'Brooch'
# Add Q19920835: 486939, Q3305213, 'Painting'
# Add Q116392130: 4829, Q95966240, 'Looking glass'
# Add Q98224495: 11445, Q860861, 'Sculpture'
# Add Q116275981: 470705, Q2745866, 'Shaft'
# Add Q116399244: 199432, Q245005, 'Teapot'
# Add Q20189590: 491682, Q11060274, 'Print'
# Add Q20177368: 15068, Q3305213, 'Painting, miniature'
# Add Q60595333: 56799, Q18219090, 'Print'
# Add Q116293211: 246418, Q1066288, 'Statuette of a woman'
#   Q97732619: Error, Met ID should be exactly one. Instead: ['392605', '392606', '398726']
# Add Q97853418: 788339, Q11060274, 'Print'
# Add Q116373713: 45, Q262026, 'Andiron'
# Add Q97581156: 294446, Q125191, 'Photograph'
# Add Q116441729: 569439, Q2442735, 'Scarab'
# Add Q20194149: 486203, Q3305213, 'Painting'
# Add Q116274835: 562303, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116314394: 44336, Q18451251, 'Goblet'
# Add Q116398912: 197460, Q179700, 'Statue'
# Add Q100379739: 155933, Q4010399, 'Dressing Gown'
# Add Q116288797: 249443, Q153988, 'Bowl, ribbed'
# Add Q116398041: 196190, Q468402, 'Tile'
# Add Q100348941: 157993, Q535576, 'Bustle'
# Add Q116373106: 684, Q153988, 'Bowl'
# Add Q97581325: 286710, Q125191, 'Photographs'
# Add Q96357787: 491995, Q11060274, 'Print'
# Add Q116406023: 255629, Q838312, 'Pin'
#   Q116445584: Error, object name lookup with Met database returned empty
# Add Q116442807: 573952, Q2442735, 'Scarab, Amenhotep II'
# Add Q116363925: 6262, Q57216, 'Plate'
# Add Q116289065: 253796, Q2442735, 'Scaraboid'
# Add Q107180229: 57877, Q23490, 'Wine bottle'
# Add Q96634253: 491327, Q11060274, 'Print'
# Add Q97579689: 268038, Q125191, 'Photograph'
# Add Q116431095: 555709, Q1478508, 'Anklet'
# Add Q19924902: 10800, Q3305213, 'Painting'
# Add Q20194714: 486288, Q3305213, 'Painting'
# Add Q116242540: 252486, Q11086465, 'Neck-amphora'
# Add Q97786641: 789562, Q11060274, 'Print'
# Add Q116317190: 35885, Q14830135, 'Powder flask'
# Add Q19921330: 483667, Q3305213, 'Drawing'
# Add Q116306671: 235836, Q499916, 'Brooch'
# Add Q116297286: 244918, Q1665351, 'Intaglio'
# Add Q116373575: 235, Q63495428, 'Side chair'
# Add Q116392167: 4929, Q2892090, 'Mantel clock'
# Add Q116310212: 200968, Q833823, 'Beaker'
# Add Q116244267: 460568, Q1207302, 'Jar'
# Add Q19913838: 437785, Q3305213, 'Painting, miniature'
# Add Q20175871: 10519, Q3305213, 'Painting'
# Add Q58755570: 40508, Q3305213, 'Handscroll'
# Add Q58755570: 40508, Q5647631, 'Handscroll'
# Add Q19913588: 438415, Q3305213, 'Painting, lunette'
# Add Q116365785: 5281, Q386215, 'Mug'
# Add Q97581403: 301993, Q125191, 'Photograph'
# Add Q116440995: 568751, Q11086567, 'Vase fragment'
# Add Q116393284: 9920, Q1531435, 'Wine glass'
# Add Q20168386: 436075, Q3305213, 'Painting'
# Add Q116391916: 3771, Q1144689, 'Folding screen'
# Add Q97767963: 396559, Q11060274, 'Print'
# Add Q19912803: 437656, Q3305213, 'Painting'
# Add Q116240940: 29335, Q830004, 'Bit'
# Add Q20177167: 15273, Q3305213, 'Painting, miniature'
# Add Q116392740: 7318, Q1422576, 'Saucer'
# Add Q97013012: 291836, Q125191, 'Daguerreotype; Stereograph'
# Add Q19924391: 11034, Q3305213, 'Painting'
# Add Q20189642: 488893, Q3305213, 'Painting'
# Add Q19920996: 486398, Q3305213, 'Painting'
# Q29388316: AttributeError for object_name: nan
# Add Q78691886: 75035, Q3305213, 'Folio'
# Add Q116308170: 198569, Q17489160, 'Bust'
# Add Q96035521: 403910, Q1190417, 'Baseball card, photograph'
# Add Q116393458: 15328, Q35473, 'Window'
# Add Q97579810: 268125, Q125191, 'Photograph'
# Add Q116287394: 254494, Q1066288, 'Statuette of Aphrodite'
# Add Q116398018: 196054, Q81727, 'Standing cup with cover'
# Add Q78808599: 51581, Q3305213, 'Album'
# Add Q116296802: 244148, Q330946, 'Dagger blade'
# Add Q116434041: 559286, Q1422576, 'Model dish, Perneb'
# Add Q116281599: 557316, Q189299, 'Necklace'
# Add Q116442030: 569626, Q2442735, 'Scarab'
# Add Q104413110: 751513, Q11460, 'War shirt'
# Add Q116444417: 647607, Q535067, 'Sauceboat'
# Add Q78750968: 54686, Q3305213, 'Album leaf'
# Add Q99807246: 90832, Q2940816, 'Jacket'
# Add Q116411544: 476436, Q40843, 'Cross'
# Add Q19917458: 486652, Q3305213, 'Painting'
# Add Q29385661: 503675, Q180733, 'Mandolin'
# Add Q116277019: 547419, Q1643900, 'Arrowhead'
# Add Q96357647: 481727, Q93184, 'Drawing'
# Add Q96586096: 491739, Q93184, 'Drawing'
# Add Q116309845: 201769, Q29527347, 'Figure'
#   Q1755464: Error, Met ID should be exactly one. Instead: ['377282', '336223', '377283', '391255']
# Add Q98823969: 771461, Q125191, 'Photograph'
# Add Q116371239: 2554, Q11083119, 'Urn'
# Add Q116726658: 61405, Q35197, 'Mirror'
# Add Q116290088: 242007, Q48634, 'Sarcophagus, anthropoid'
# Add Q20200313: 487672, Q860861, 'Sculpture'
# Add Q116441397: 569050, Q11086567, 'Ring fragment, bezel'
# Add Q116441397: 569050, Q33269774, 'Ring fragment, bezel'
# Add Q116344658: 8390, Q245005, 'Teapot'
# Add Q19920945: 483201, Q3305213, 'Painting'
# Add Q116310110: 203403, Q11422, 'Toy'
# Add Q116392890: 8326, Q245005, 'Teapot'
# Add Q116295117: 246300, Q1066288, 'Statuette of Herakles'
# Add Q97852614: 775598, Q11060274, 'Print'
# Add Q116415668: 548785, Q39397, 'Ax'
# Add Q116289161: 249429, Q153988, 'Bowl, ribbed'
# Add Q116242483: 205520, Q151771, 'Candlestick'
# Add Q116390598: 1348, Q151771, 'Candlestick'
# Add Q20182735: 460924, Q10672725, 'Snuffbox'
# Add Q20182906: 459174, Q3305213, 'Painting'
# Add Q116362292: 6517, Q3391771, 'Platter'
# Add Q19923629: 487032, Q3305213, 'Painting'
# Add Q104413088: 717564, Q96091671, 'Water jar'
# Add Q96586136: 687752, Q595597, 'Negative'
# Add Q20176244: 10852, Q3305213, 'Painting'
# Add Q116345087: 9321, Q191851, 'Vase'
# Add Q116307566: 208284, Q245005, 'Teapot with cover'
# Add Q78752649: 54641, Q3305213, 'Album leaf'
# Add Q20187691: 461446, Q3305213, 'Frame'
# Add Q78714781: 72570, Q3305213, 'Hanging scroll'
# Add Q116291708: 248210, Q2442735, 'Scarab'
# Add Q116305274: 640179, Q101401, 'Bell'
# Add Q96181612: 268700, Q125191, 'Photograph'
# Add Q116438793: 562348, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q19923992: 10471, Q3305213, 'Painting'
# Add Q116364313: 5533, Q914149, 'Paperweight'
# Add Q96800561: 268343, Q125191, 'Photograph'
# Add Q104213113: 263168, Q125191, 'Photograph'
# Add Q116242737: 444600, Q404785, 'Ewer'
# Add Q116394444: 26556, Q23954892, 'Smallsword'
# Add Q116444941: 751615, Q188075, 'Box'
# Add Q116290030: 247561, Q1066288, 'Statuette of a woman'
# Add Q116438843: 562399, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116394205: 22925, Q23954892, 'Smallsword'
# Add Q18627442: 285461, Q125191, 'Photograph'
# Add Q116338503: 7575, Q131514, 'Sofa'
# Add Q78852068: 44625, Q3305213, 'Hanging scroll'
# Add Q116432142: 556517, Q2442735, 'Scarab'
# Add Q19930626: 11891, Q18761202, 'Watercolor'
# Add Q116272717: 587763, Q162919, 'Sealing'
# Add Q116306151: 236768, Q201664, 'Bracelet'
# Add Q20201192: 466589, Q860861, 'Statuette'
# Add Q19922230: 492554, Q3305213, 'Drawing'
# Add Q78620855: 670923, Q3305213, 'Handscroll'
# Add Q116331497: 9154, Q16180001, 'Tumbler'
# Add Q19914004: 435800, Q3305213, 'Painting, miniature'
# Add Q116273249: 469030, Q95870182, 'Strap end'
# Add Q116393644: 19869, Q191851, 'Vase'
# Add Q29384647: 335240, Q93184, 'Drawing'
# Add Q20200883: 471061, Q3305213, 'Fresco fragment'
# Add Q116241548: 45634, Q987767, 'Wine container'
# Add Q116365717: 5333, Q386215, 'Cann'
# Add Q116432634: 557229, Q11086567, 'Vase fragment'
# Add Q116438810: 562366, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q20188314: 462594, Q3305213, 'Bowl'
# Add Q116240827: 191804, Q179700, 'Statue'
# Add Q116371271: 2534, Q107444, 'Teakettle'
# Add Q59590708: 334324, Q93184, 'Drawing'
# Add Q116390411: 1025, Q499916, 'Brooch'
# Add Q116394183: 22759, Q830004, 'Bit'
# Add Q116244429: 466185, Q2111434, 'Harness pendant'
# Add Q116309672: 197563, Q245005, 'Teapot'
# Add Q19920718: 484433, Q3305213, 'Painting'
# Add Q116310691: 194293, Q6806674, 'Pharmacy jar'
# Add Q78722434: 57350, Q3305213, 'Painted panel'
# Add Q116405261: 254859, Q178401, 'Amphora'
# Add Q96185389: 557766, Q3305213, 'Facsimile, Pairy (TT 139), funeral'
# Add Q116445175: 810946, Q201664, 'Bracelet'
# Add Q20178068: 12730, Q18761202, 'Watercolor'
# Add Q116297172: 240101, Q668349, 'Kylix'
# Add Q116432217: 556581, Q5174015, 'Kohl jar'
# Add Q78699534: 74997, Q3305213, 'Folio'
# Add Q116363579: 6431, Q57216, 'Plate'
# Add Q116324553: 18238, Q81895, 'Spoon'
# Add Q116272795: 464380, Q57216, 'Plate'
# Add Q78841934: 45703, Q3305213, 'Painting'
# Add Q116392760: 7343, Q6653030, 'Sconce'
# Add Q116246026: 460160, Q1888893, 'Albarello'
# Add Q96185525: 764083, Q11060274, 'Valentine'
# Add Q19913738: 439273, Q3305213, 'Painting, drawing'
# Add Q98820342: 261120, Q125191, 'Photograph'
# Add Q19924525: 15036, Q3305213, 'Painting, miniature'
# Add Q20172673: 11712, Q3305213, 'Painting'
# Add Q116390505: 1209, Q151771, 'Candlestick'
# Add Q116311454: 193707, Q2111434, 'Pendant'
# Add Q116247992: 471807, Q746549, 'Dish'
# Add Q116401496: 240365, Q81727, 'Cup'
# Add Q116353736: 6038, Q57216, 'Plate'
# Add Q116250567: 39317, Q1497375, 'Architectural ensemble'
# Add Q116250567: 39317, Q43694649, 'Architectural ensemble'
# Add Q96185419: 557814, Q3305213, 'Facsimile, Panehsy (TT 16), Amenhotep I, palanquin, sphinx; Drink-and-be-Merry'
# Add Q116287163: 255529, Q831869, 'Oinochoe'
# Add Q116372400: 1309, Q151771, 'Candlestick'
# Add Q19923427: 485188, Q3305213, 'Painting'
# Add Q20197683: 488614, Q3305213, 'Painting'
# Add Q116404180: 252487, Q11086465, 'Neck-amphora'
# Add Q116402254: 245833, Q245117, 'Stucco relief'
# Add Q97012694: 286410, Q125191, 'Photograph'
# Add Q116306978: 206458, Q57216, 'Plate'
# Add Q116280529: 467630, Q179700, 'Statue'
# Add Q19913751: 435699, Q3305213, 'Painting, miniature'
# Add Q116371824: 2010, Q14169227, 'Chest of drawers'
# Add Q116441045: 568793, Q11086567, 'Vase fragment'
# Add Q116275418: 561835, Q28823, 'Linen Mark'
# Add Q116310558: 195910, Q81727, 'Standing cup with cover'
# Add Q116310694: 197810, Q22075301, 'Length'
# Add Q116295088: 248087, Q548275, 'Candelabrum'
# Add Q116341254: 7474, Q7500017, 'Shoe buckle'
# Add Q116393195: 9463, Q191851, 'Vase'
# Add Q100347782: 139874, Q200539, 'Dress'
# Add Q116287937: 257433, Q3305213, 'Portrait of a woman'
# Add Q20197048: 486611, Q3305213, 'Painting'
# Add Q116295618: 246220, Q746549, 'Dish'
# Add Q116432083: 556470, Q2442735, 'Scarab'
# Add Q19925607: 18447, Q3305213, 'Painting'
# Add Q20187123: 459071, Q3305213, 'Painting'
# Add Q96053338: 404438, Q1190417, 'Baseball card, photograph'
# Add Q116371439: 2397, Q1207302, 'Jar'
# Add Q116393050: 8923, Q2569925, 'Trivet'
# Add Q116404864: 254457, Q2442735, 'Scaraboid'
# Add Q112063538: 44887, Q720106, 'Handscroll'
# Add Q116389794: 63387, Q11060274, 'Print'
#   Q29388417: Error, object name lookup with Met database returned empty
# Add Q116370601: 3256, Q746549, 'Dish'
# Add Q116305545: 239700, Q2413314, 'Jug'
# Add Q78723188: 57318, Q3305213, 'Hanging scroll'
# Add Q19913977: 435999, Q3305213, 'Painting, miniature'
# Add Q116441828: 569489, Q2442735, 'Scarab'
# Add Q116395467: 42212, Q80228, 'Bottle'
# Add Q40432: 435702, Q3305213, 'Painting'
# Add Q116385568: 449102, Q193893, 'Capital'
# Add Q19917457: 488783, Q3305213, 'Painting'
# Add Q116445097: 771051, Q153988, 'Bowl'
# Q29388312: AttributeError for object_name: nan
# Add Q20172045: 13357, Q3305213, 'Painting'
# Add Q96807171: 284029, Q125191, 'Photograph'
# Add Q116444018: 625715, Q726826, 'Shabti, worker, Nauny'
# Add Q63362066: 44943, Q18219090, 'Print'
# Add Q19924771: 12707, Q3305213, 'Painting'
# Add Q78693459: 75027, Q3305213, 'Folio'
# Add Q20201763: 471926, Q179700, 'Statue'
# Add Q116298713: 644896, Q29401129, 'Statue head'
#   Q97579707: Error, object name lookup with Met database returned empty
# Add Q116441049: 568798, Q11086567, 'Vase fragment'
# Add Q19919531: 632936, Q3305213, 'Painting'
# Add Q116308418: 208003, Q131647, 'Medal'
# Add Q116306109: 236772, Q2111434, 'Pendant brooch'
# Add Q116306109: 236772, Q499916, 'Pendant brooch'
# Add Q116396317: 49862, Q191851, 'Vase'
# Add Q96185496: 693833, Q11060274, 'Print'
# Add Q116246222: 591033, Q726826, 'Shabti, Henettawy C'
# Add Q19905313: 435745, Q3305213, 'Painting'
# Add Q20195689: 482999, Q3305213, 'Painting'
# Add Q19923116: 486653, Q3305213, 'Drawing'
# Add Q78709064: 74682, Q3305213, 'Drawing'
# Add Q20198658: 484425, Q3305213, 'Painting'
# Add Q116440513: 568167, Q4364339, 'Foundation Deposit Plaque, rectangular'
# Add Q83560018: 379, Q833823, 'Beaker'
# Add Q19925507: 13176, Q18761202, 'Watercolor'
# Add Q61363155: 788905, Q3305213, 'Painting'
# Add Q116246710: 552601, Q131557, 'Amulet, Taweret'
# Add Q116314812: 40116, Q7295963, 'Rattle'
# Add Q97012940: 291819, Q125191, 'Daguerreotype'
# Add Q78822848: 49463, Q3305213, 'Folding fan mounted as an album leaf'
# Add Q98821522: 289506, Q125191, 'Photograph'
# Add Q116393309: 9971, Q1531435, 'Wine glass'
# Add Q20194594: 486239, Q3305213, 'Painting'
# Add Q116289228: 248527, Q11086567, 'Vase fragment'
# Add Q96802952: 269462, Q125191, 'Photograph'
# Add Q78742564: 54974, Q3305213, 'Hanging scroll'
# Add Q29384395: 318764, Q860861, 'Couple figure'
# Add Q19924032: 12169, Q18761202, 'Watercolor'
# Add Q19924032: 12169, Q93184, 'Watercolor'
# Add Q116357446: 6776, Q29527347, 'Figure'
# Add Q97852881: 787707, Q11060274, 'Print'
# Add Q78995779: 36048, Q3305213, 'Handscroll'
# Add Q97770783: 739023, Q11060274, 'Print'
# Add Q116445572: 852566, Q11060274, 'Print'
# Add Q116431000: 555640, Q245117, 'Relief'
# Add Q116392307: 5503, Q678883, 'Paneling'
# Add Q96756837: 653751, Q93184, 'Drawing'
# Add Q97732265: 389075, Q11060274, 'Print'
# Add Q96181592: 266258, Q125191, 'Photograph'
# Add Q19913048: 435832, Q3305213, 'Painting'
# Add Q116393509: 16817, Q499916, 'Brooch'
# Add Q116288245: 248673, Q1066288, 'Statuette of Herakles'
# Add Q97852598: 775517, Q11060274, 'Print'
# Add Q20176973: 16725, Q3305213, 'Painting, miniature'
# Add Q116393369: 12960, Q335261, 'Ornament'
# Add Q19925475: 11518, Q3305213, 'Painting'
# Add Q100709862: 107712, Q200539, 'Dress'
# Add Q97012665: 286280, Q125191, 'Photograph'
# Add Q20191234: 653753, Q3305213, 'Painting'
# Add Q19917872: 486949, Q3305213, 'Drawing'
# Add Q98823538: 285345, Q125191, 'Photograph'
# Add Q83562802: 80389, Q200539, 'Dress'
# Add Q116280200: 447966, Q11086567, 'Fragment'
# Add Q19924550: 15169, Q3305213, 'Painting, miniature'
# Add Q78626108: 473058, Q3305213, 'Painting'
# Add Q116314304: 42088, Q29527347, 'Figure'
# Add Q116370462: 3411, Q10550521, 'Parlor'
# Add Q78871177: 39569, Q3305213, 'Handscroll'
# Add Q97579616: 267979, Q125191, 'Photograph'
# Add Q116390310: 639, Q80228, 'Bottle'
# Add Q116371018: 8411, Q245005, 'Teapot'
# Add Q116275421: 468397, Q2413314, 'Jug'
# Add Q116444345: 625931, Q726826, 'Shabti, worker, Nauny'
# Add Q116288028: 251448, Q717954, 'Aryballos'
# Add Q96035645: 403981, Q1190417, 'Baseball card, photograph'
# Add Q19905372: 437382, Q3305213, 'Painting'
# Add Q116291696: 245454, Q673338, 'Alabastron'
# Add Q55594040: 439977, Q3305213, 'Painting'
# Add Q97732020: 388773, Q11060274, 'Print'
# Add Q101483072: 335080, Q93184, 'Drawing'
# Add Q116310258: 207238, Q10672725, 'Snuffbox'
# Add Q96183025: 291552, Q125191, 'Photogram'
# Add Q116295490: 247190, Q717954, 'Aryballos'
# Add Q116373889: 230934, Q1066288, 'Statuette'
# Add Q116247923: 451041, Q153988, 'Bowl'
# Add Q96185502: 696209, Q11060274, 'Print'
# Add Q83562253: 40509, Q5647631, 'Handscroll'
# Add Q116297493: 244889, Q1665351, 'Intaglio'
# Add Q19905144: 437676, Q3305213, 'Painting'
# Add Q98823874: 659461, Q192425, 'Postcard'
# Add Q19917561: 483157, Q3305213, 'Drawing'
# Add Q97579681: 268031, Q125191, 'Photograph'
# Add Q116440467: 568130, Q224104, 'Foundation Deposit Plaque, cartouche'
# Add Q116440467: 568130, Q4364339, 'Foundation Deposit Plaque, cartouche'
# Add Q116273107: 469160, Q231455, 'Solidus'
# Add Q116402821: 251079, Q153988, 'Bowl'
# Add Q96357836: 495256, Q93184, 'Drawing'
# Add Q116282541: 322488, Q245117, 'Relief'
# Add Q116441344: 569005, Q46847, 'Ring'
# Add Q116392366: 5988, Q57216, 'Plate'
# Add Q116273204: 569311, Q46847, 'Ring'
# Add Q78829204: 49075, Q3305213, 'Hanging scroll'
# Add Q96793337: 261483, Q125191, 'Photograph'
# Add Q116414766: 546641, Q1053956, 'Bead'
# Add Q96800589: 268355, Q125191, 'Photograph'
# Add Q96183061: 291561, Q125191, 'Photogram'
# Add Q116359665: 5802, Q132397, 'Pitcher'
# Add Q20177038: 15202, Q3305213, 'Painting, miniature'
# Add Q98821241: 269899, Q125191, 'Photograph'
# Add Q116289355: 254935, Q960844, 'Cinerary urn'
# Add Q116371128: 2657, Q60310748, 'Cream pot'
# Add Q78752565: 54642, Q3305213, 'Album leaf'
# Add Q78737314: 57173, Q3305213, 'Hanging scroll'
# Add Q20200676: 488016, Q46847, 'Ring'
# Add Q116240881: 43946, Q101401, 'Bell'
# Add Q78638736: 438126, Q3305213, 'Painting'
# Add Q20171749: 13049, Q3305213, 'Painting'
# Add Q116370576: 3288, Q746549, 'Dish'
# Add Q116392621: 6867, Q46847, 'Ring'
# Add Q83562043: 37620, Q29527347, 'Figure'
# Add Q78702205: 74911, Q3305213, 'Folio'
# Add Q95986506: 3979, Q1326509, 'Girandole'
# Add Q20177850: 21655, Q860861, 'Sculpture'
# Add Q116287776: 251529, Q65769142, 'Stamp'
# Add Q116295794: 240727, Q191851, 'Vase'
# Add Q96181408: 157153, Q200539, 'Evening dress'
# Add Q96035651: 404084, Q1190417, 'Baseball card, photograph'
# Add Q29961418: 694642, Q3305213, 'Painting'
# Add Q116289563: 249317, Q746549, 'Dish'
# Add Q116307293: 207103, Q29527347, 'Figure'
# Add Q116444735: 718117, Q914149, 'Paperweight'
# Add Q19921206: 491762, Q3305213, 'Drawing'
# Add Q116392496: 6351, Q57216, 'Plate'
# Add Q116373095: 692, Q153988, 'Bowl'
# Add Q20198222: 490814, Q3305213, 'Painting'
# Add Q97771754: 736914, Q11060274, 'Print'
# Add Q116296970: 240181, Q1136095, 'Skyphos'
# Add Q97771900: 742650, Q11060274, 'Print'
# Add Q97579072: 259606, Q1757923, 'Carte-de-visite'
# Add Q116310125: 195414, Q622360, 'Commode'
# Add Q116370487: 3387, Q979617, 'Egg cup'
# Add Q116395217: 40744, Q191851, 'Vase'
# Add Q59567425: 55138, Q18219090, 'Print'
# Add Q116297358: 239989, Q178401, 'Amphora'
# Add Q116442939: 575880, Q131557, 'Amulet, Djed pillar'
# Add Q20201160: 471972, Q3305213, 'Game piece'
# Add Q116290048: 245616, Q15407662, 'Calyx-krater'
# Add Q78796696: 51769, Q3305213, 'Handscroll'
# Add Q116295596: 247176, Q476968, 'Krater'
# Add Q20173464: 12578, Q3305213, 'Painting'
# Add Q97827134: 843780, Q11060274, 'Print'
# Add Q116405697: 255352, Q745783, 'Hydria, kalpis'
# Add Q116321043: 38612, Q746549, 'Dish'
# Add Q116293703: 249814, Q673338, 'Alabastron'
# Add Q20191789: 490226, Q3305213, 'Drawing'
# Add Q19918451: 493196, Q3305213, 'Drawing'
# Add Q20199045: 488428, Q3305213, 'Drawing'
# Add Q96585956: 491314, Q11060274, 'Print'
# Add Q116392900: 8442, Q81895, 'Spoon'
# Add Q19905214: 437222, Q3305213, 'Painting'
# Add Q116244226: 473637, Q83893, 'Ingot'
# Add Q20201888: 471996, Q3305213, 'Reliquary bust'
# Add Q97853048: 788045, Q11060274, 'Print'
# Add Q116373917: 208538, Q17489160, 'Bust'
# Add Q116289042: 248560, Q11086567, 'Vase fragment'
# Add Q19920227: 487051, Q860861, 'Sculpture'
# Add Q116409596: 449798, Q153988, 'Bowl'
# Add Q29385199: 452112, Q1363377, 'Folio from an illustrated manuscript'
# Add Q29385199: 452112, Q678664, 'Folio from an illustrated manuscript'
# Add Q116444388: 628198, Q860861, 'Sculpture'
# Add Q97854178: 811999, Q11060274, 'Print'
# Add Q100347117: 82144, Q2001719, 'Pelisse'
# Add Q19914234: 436683, Q3305213, 'Painting'
# Add Q20187058: 459060, Q3305213, 'Painting'
# Add Q116374348: 39950, Q245117, 'Relief fragment'
# Add Q116274121: 449135, Q11086567, 'Tile fragment'
# Add Q116274121: 449135, Q468402, 'Tile fragment'
# Add Q116333909: 7763, Q81895, 'Spoon'
# Add Q97827132: 843777, Q11060274, 'Print'
# Add Q116432256: 556617, Q2442735, 'Scarab'
# Add Q116370781: 2976, Q50386939, 'Curtain knob'
# Add Q116242507: 205428, Q191851, 'Vase'
# Add Q116307573: 207022, Q1066288, 'Statuette'
# Add Q97852296: 775461, Q11060274, 'Print'
# Add Q116401331: 237993, Q63495428, 'Side chair'
# Add Q20198011: 492374, Q22075301, 'Textile'
# Add Q20198011: 492374, Q29639251, 'Textile'
# Add Q116371440: 2396, Q1207302, 'Jar'
# Add Q20186249: 459170, Q3305213, 'Painting'
# Add Q20181217: 460417, Q193220, 'Fan'
# Add Q100709758: 106979, Q200539, 'Morning dress'
# Add Q19913317: 437140, Q3305213, 'Painting, miniature'
# Add Q20170044: 12471, Q3305213, 'Painting'
# Add Q78700174: 74992, Q3305213, 'Folio'
# Add Q20190830: 488481, Q3305213, 'Painting'
# Add Q116365368: 5463, Q821952, 'Whale oil lamp'
# Add Q116313667: 50321, Q46847, 'Ring'
# Add Q116411788: 484698, Q548275, 'Candelabrum'
# Add Q116441829: 569490, Q2442735, 'Scarab'
# Add Q116397387: 186460, Q80228, 'Bottle'
# Add Q116314231: 42746, Q33163, 'Stool'
# Add Q97788363: 811148, Q11060274, 'Print'
# Add Q19911948: 439118, Q3305213, 'Painting'
# Add Q83562472: 44881, Q2741056, 'Cabinet'
# Add Q116242796: 446176, Q1363377, 'Folio from a non-illustrated manuscript'
# Add Q116726667: 43248, Q1066288, 'Figures'
# Add Q116326639: 22000, Q50414774, 'Armor'
# Add Q116280558: 461628, Q860792, 'Frame'
# Add Q116367677: 4005, Q11086567, 'Fragment'
# Add Q96357609: 354212, Q53731850, 'Book'
# Add Q116287868: 251506, Q838312, 'Pin'
# Add Q116441382: 569039, Q11086567, 'Ring fragment, bezel'
# Add Q116441382: 569039, Q33269774, 'Ring fragment, bezel'
# Add Q116370454: 3422, Q2106696, 'Dressing table'
# Add Q19904878: 436929, Q3305213, 'Painting'
# Add Q116289352: 245723, Q1350279, 'Pyxis with lid'
# Add Q116289352: 245723, Q2488579, 'Pyxis with lid'
# Add Q20201995: 479575, Q3305213, 'Manuscript leaf'
# Add Q116373552: 1879, Q63495428, 'Side Chair'
# Add Q116391925: 3785, Q16180001, 'Tumbler'
# Add Q78741380: 55297, Q3305213, 'Hanging scroll'
# Add Q116400941: 209068, Q2356786, 'Sugar bowl'
# Add Q116371972: 1763, Q11285759, 'Armchair'
# Add Q98822541: 261740, Q125191, 'Photograph'
# Add Q116374471: 38980, Q29527347, 'Figure'
# Add Q116272608: 550318, Q2442735, 'Scarab, Ramesses II'
# Add Q97579661: 268018, Q125191, 'Photograph'
# Add Q19921137: 484866, Q3305213, 'Drawing'
# Add Q79013381: 16744, Q3305213, 'Painting'
# Add Q20198996: 484504, Q3305213, 'Drawing'
# Add Q116244526: 473290, Q2111434, 'Pendant'
# Add Q19911828: 437596, Q3305213, 'Painting, drawing'
# Add Q116252455: 471146, Q4817, 'Column'
# Add Q116422156: 553565, Q1053956, 'Bead'
# Add Q116276356: 478988, Q132397, 'Pitcher'
# Add Q116252710: 470981, Q193893, 'Capital'
# Add Q116370217: 3727, Q18696213, 'Flask'
# Add Q116310341: 197478, Q1066288, 'Statuette group'
# Add Q116310341: 197478, Q1497375, 'Statuette group'
# Add Q19924243: 12612, Q3305213, 'Painting, miniature'
# Add Q20184499: 459073, Q3305213, 'Painting'
# Add Q78795628: 51800, Q3305213, 'Handscroll'
# Add Q116393095: 8956, Q2569925, 'Trivet'
# Add Q19917730: 632986, Q3305213, 'Painting'
# Add Q116274933: 562205, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116366068: 4856, Q95966240, 'Looking glass'
# Add Q116355639: 5971, Q57216, 'Plate'
# Add Q116367352: 4262, Q29527347, 'Figure'
# Add Q78618681: 670974, Q3305213, 'Albums'
# Add Q116370552: 3315, Q746549, 'Dish'
# Add Q116373691: 88, Q262026, 'Andiron'
# Add Q19924396: 19228, Q3305213, 'Watercolor'
# Add Q20198703: 485076, Q3305213, 'Drawing'
# Add Q116357728: 6719, Q3579073, 'Porringer'
# Add Q96585017: 371999, Q11060274, 'Print'
# Add Q96635156: 650159, Q125191, 'Photograph'
# Add Q116306598: 236108, Q622360, 'Commode'
# Add Q116434253: 559320, Q1422576, 'Model dish, Perneb'
# Add Q96357645: 383685, Q11060274, 'Print'
# ...
# Add Q116281847: 452064, Q191851, 'Vase'
# Add Q20188105: 460529, Q404785, 'Pitcher'
# Add Q20189686: 483873, Q3305213, 'Painting'
# Add Q97579192: 267890, Q125191, 'Photograph'
# Add Q20198980: 484416, Q3305213, 'Painting'
# Add Q116288590: 248584, Q1350279, 'Pyxis'
# Add Q116295800: 240653, Q80228, 'Bottle'
# Add Q116243366: 556601, Q188075, 'Box, cosmetic'
# Add Q19925498: 19301, Q3305213, 'Painting'
# Add Q116242630: 444985, Q404785, 'Ewer'
# Add Q116252871: 470845, Q193893, 'Capital'
# Add Q19923947: 10858, Q3305213, 'Painting'
# Add Q20196843: 485196, Q3305213, 'Painting'
# Add Q100706248: 90871, Q29353484, 'Ensemble'
# Add Q116235288: 548462, Q746549, 'Dish'
# Add Q116370971: 2764, Q81727, 'Cup'
# Add Q116370578: 3284, Q746549, 'Dish'
# Add Q116310736: 196470, Q1066288, 'Statuette'
# Add Q116351832: 6113, Q57216, 'Plate'
# Add Q116295295: 248059, Q208041, 'Sestertius'
# Add Q116400873: 208344, Q746549, 'Dish'
# Add Q116335049: 9000, Q16180001, 'Tumbler'
# Add Q61876908: 65008, Q559065, 'Robe'
# Add Q98821562: 296315, Q125191, 'Photograph'
# Add Q20198732: 486158, Q14745, 'Sculpture'
# Add Q19913053: 436192, Q3305213, 'Painting'
# Add Q19920249: 495130, Q3305213, 'Painting'
# Add Q116439037: 562565, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q116335986: 7674, Q87718085, 'Soup plate'
# Add Q96195274: 765823, Q11060274, 'Valentine'
# Add Q116289466: 247656, Q11086567, 'Vase fragment'
# Add Q19911487: 437795, Q3305213, 'Painting'
# Add Q116402216: 243953, Q153988, 'Bowl'
# Add Q116364610: 6191, Q57216, 'Plate'
# Add Q116310610: 201414, Q115488, 'Medallion'
# Add Q20172966: 19272, Q3305213, 'Painting'
# Add Q116340830: 8107, Q81895, 'Spoon'
#   Q19918832: Error, object name lookup with Met database returned empty
# Add Q100347224: 86871, Q200539, 'Dress'
# Add Q116373226: 573, Q468402, 'Tile'
# Add Q20167172: 437331, Q3305213, 'Painting'
# Add Q116288970: 250095, Q1350279, 'Pyxis with lid'
# Add Q116288970: 250095, Q2488579, 'Pyxis with lid'
# Add Q116404154: 252456, Q921668, 'Stater'
# Add Q116234844: 21975, Q173603, 'Helmet'
# Add Q96182178: 291522, Q841954, 'Photogram'
# Add Q78760445: 53210, Q3305213, 'Hanging scroll'
# Add Q116242792: 445026, Q1348059, 'Panel'
# Add Q116441663: 569371, Q46847, 'Ring'
# Add Q20170003: 10467, Q3305213, 'Painting'
# Add Q116295565: 240834, Q2413314, 'Jug'
# Add Q97788731: 811332, Q11060274, 'Print'
# Add Q100706427: 108156, Q29353484, 'Ensemble'
# Add Q96035571: 403934, Q1190417, 'Baseball card, photograph'
# Add Q19912215: 436221, Q3305213, 'Painting'
# Add Q98822705: 265159, Q125191, 'Multiple exposure; Photograph'
# Add Q116292145: 245394, Q153988, 'Bowl'
# Add Q116374394: 39161, Q29527347, 'Figure'
# Add Q20201559: 471104, Q3305213, 'Roundel'
# Add Q116374462: 39007, Q29527347, 'Figure'
# Add Q29385311: 459198, Q17379525, 'Plate'
# Add Q29385901: 547687, Q15026, 'Chair, Reniseneb'
# Add Q19912739: 437750, Q3305213, 'Painting'
# Add Q116353716: 6040, Q57216, 'Plate'
# Add Q116372365: 1339, Q151771, 'Candlestick'
# Add Q110026460: 846917, Q15026, 'Chair'
# Add Q78861296: 40303, Q3305213, 'Handscroll'
# Add Q78861296: 40303, Q5647631, 'Handscroll'
# Add Q19917488: 488668, Q3305213, 'Painting'
# Add Q116393010: 8892, Q2569925, 'Trivet'
# Add Q20185347: 458974, Q3305213, 'Painting'
# Add Q83560072: 5401, Q189299, 'Necklace'
# Add Q96035418: 403788, Q1190417, 'Baseball card, photograph'
# Add Q116296967: 248703, Q860861, 'Head of a youth'
# Add Q116400225: 204635, Q11285759, 'Armchair'
# Add Q96195289: 765075, Q11060274, 'Valentine'
# Add Q116290093: 245601, Q1136095, 'Skyphos'
# Add Q20185104: 459409, Q3305213, 'Drawing'
# Add Q97854120: 811952, Q11060274, 'Print'
# Add Q116365757: 5307, Q386215, 'Mug'
# Add Q116246021: 460161, Q57216, 'Plate'
# Add Q116243399: 556508, Q1123756, 'Cylinder seal'
# Add Q116235489: 470294, Q499916, 'Brooch'
# Add Q97786668: 810828, Q11060274, 'Print'
# Add Q96634258: 491352, Q11060274, 'Print'
# Add Q116431889: 556323, Q2442735, 'Scarab'
# Add Q116372038: 1661, Q15026, 'Chair'
# Add Q20199469: 495271, Q93184, 'Drawing'
# Add Q116431979: 556392, Q2442735, 'Scarab'
# Add Q100706409: 107957, Q200539, 'Dress'
# Add Q29385086: 449211, Q321053, 'Panel'
# Add Q116307359: 209246, Q115488, 'Medallion'
# Add Q17813915: 436619, Q3305213, 'Painting'
# Add Q116316575: 40609, Q11086567, 'Fragment'
# Add Q79000696: 36008, Q3305213, 'Fan mounted as an album leaf'
# Add Q116306347: 231605, Q81895, 'Spoon'
# Add Q116275353: 561876, Q28823, 'Linen Mark'
# Add Q97581365: 294724, Q125191, 'Photograph'
# Add Q78850435: 44983, Q3305213, 'Hanging scroll'
# Add Q96748809: 457790, Q3305213, 'Painting'
# Add Q116307193: 207149, Q29527347, 'Figure'
# Add Q116429566: 555311, Q131557, 'Amulet'
# Add Q116310201: 193555, Q81727, 'Cup with cover'
# Add Q116310201: 193555, Q2488579, 'Cup with cover'
# Add Q116429705: 555329, Q131557, 'Amulet'
# Add Q116390624: 1365, Q151771, 'Candlestick'
# Add Q83562533: 49805, Q2188827, 'Hanging scroll'
# Add Q20177805: 14307, Q3305213, 'Painting, miniature'
# Add Q116274030: 464111, Q95870182, 'Strap end'
# Add Q116376748: 38480, Q4364339, 'Votive plaque'
# Add Q116245572: 451368, Q1125338, 'Bookbinding'
# Add Q116358959: 5820, Q60310748, 'Cream pot'
# Add Q116341479: 7456, Q1135567, 'Buckle'
# Add Q116342920: 7351, Q6653030, 'Sconce'
# Add Q19913136: 437687, Q3305213, 'Painting'
# Add Q116445107: 773198, Q499916, 'Brooch'
# Add Q116372289: 1418, Q53688576, 'Card table'
# Add Q96053320: 404415, Q1190417, 'Baseball card, photograph'
# Add Q29385430: 466296, Q184856, 'Pointer tip'
# Add Q19923924: 15151, Q3305213, 'Painting, miniature'
# Add Q96585969: 491334, Q11060274, 'Print'
# Add Q78851100: 44861, Q3305213, 'Hanging scroll'
# Add Q19911951: 438676, Q3305213, 'Painting'
# Add Q116359966: 6640, Q29527347, 'Figure'
# Add Q116390318: 643, Q80228, 'Bottle'
# Add Q19911580: 436941, Q3305213, 'Painting'
# Add Q78829060: 49080, Q3305213, 'Hanging scroll'
# Add Q78878147: 37981, Q3305213, 'Folio'
# Add Q116331845: 7796, Q81895, 'Spoon'
# Add Q78693897: 75025, Q3305213, 'Folio'
# Add Q19920652: 489238, Q3305213, 'Painting'
# Add Q19911968: 436068, Q3305213, 'Painting'
# Add Q116295585: 240787, Q153988, 'Bowl'
#   Q20168393: Error, object name lookup with Met database returned empty
# Add Q78710847: 74648, Q3305213, 'Painting'
# Add Q116400183: 204273, Q1066288, 'Statuette'
# Add Q116280486: 546974, Q726826, 'Shabti'
# Add Q116356770: 5887, Q132397, 'Pitcher'
# Add Q19913793: 436466, Q3305213, 'Painting, miniature'
# Add Q97853198: 788317, Q11060274, 'Print'
# Add Q78811900: 51526, Q3305213, 'Handscroll'
# Add Q78802652: 51682, Q3305213, 'Album leaf'
# Add Q78851553: 44794, Q3305213, 'Wall painting'
# Add Q83562019: 32368, Q860861, 'Sculpture'
# Add Q20176591: 635395, Q3305213, 'Painting'
# Add Q78694908: 75020, Q3305213, 'Folio'
# Add Q78725638: 57279, Q3305213, 'Drawing'
# Add Q116414862: 546780, Q6105860, 'Headrest'
# Add Q20200796: 483133, Q3305213, 'Drawing'
# Add Q116370388: 3521, Q979617, 'Egg cup'
# Add Q116294741: 241030, Q860861, 'Head of a man'
# Add Q19913446: 437567, Q3305213, 'Painting, icons'
# Add Q19911462: 436669, Q3305213, 'Painting'
# Add Q78884019: 37876, Q3305213, 'Painting'
# Add Q116253152: 457133, Q41207, 'Coin'
# Add Q116374406: 39128, Q29527347, 'Figure'
# Add Q20201619: 471029, Q21061279, 'Stained glass panel'
# Add Q106357246: 12056, Q3305213, 'Watercolor'
# Add Q19911611: 437157, Q3305213, 'Painting'
# Add Q20173718: 12705, Q3305213, 'Painting'
# Add Q98823228: 267534, Q125191, 'Photograph'
# Add Q116244032: 451713, Q153988, 'Bowl'
# Add Q96053651: 412450, Q1190417, 'Baseball card'
# Add Q116402704: 250952, Q831869, 'Oinochoe'
# Add Q116385368: 444864, Q41207, 'Coin'
# Add Q116365895: 4975, Q4364339, 'Plaque'
# Add Q96185384: 557761, Q3305213, 'Facsimile, Amenemhat Surer (TT 48), inscription'
# Add Q62589709: 78633, Q18219090, 'Illustrated books'
# Add Q19923812: 11471, Q3305213, 'Painting'
# Add Q97786633: 789556, Q11060274, 'Print'
# Add Q75196935: 11271, Q12043905, 'Drawing'
# Add Q96586115: 687741, Q595597, 'Negative'
# Add Q96399251: 830456, Q860861, 'Sculpture'
# Add Q116255989: 470674, Q2745866, 'Shaft'
# Add Q116355514: 5968, Q57216, 'Plate'
# Add Q19917729: 489404, Q3305213, 'Painting'
# Add Q78833767: 48946, Q3305213, 'Hanging scroll'
# Add Q97417807: 208052, Q3666631, 'Secretary'
# Add Q96185302: 544639, Q3305213, 'Facsimile, Rekhmire (TT 100), carpenters'
# Add Q78880295: 37947, Q3305213, 'Folio'
# Add Q116244880: 466117, Q153988, 'Bowl'
# Add Q116366819: 4480, Q1207302, 'Jar'
# Add Q97581385: 301937, Q125191, 'Photograph'
# Add Q97850021: 757600, Q11060274, 'Print'
# Add Q116288560: 254269, Q673338, 'Alabastron'
# Add Q19917824: 488623, Q3305213, 'Painting'
# Add Q20200701: 495377, Q499916, 'Brooch'
# Add Q116247985: 451028, Q163446, 'Carpet'
# Add Q116289678: 248409, Q860861, 'Head of a woman'
# Add Q116396335: 49914, Q191851, 'Vase'
# Add Q116256148: 472335, Q208454, 'Abacus'
# Add Q97012955: 291834, Q125191, 'Daguerreotype'
# Add Q116310088: 199030, Q153988, 'Bowl'
# Add Q116370833: 2934, Q18349459, 'Cup plate'
# Add Q100145588: 81790, Q11284623, 'Afternoon dress'
# Add Q116276485: 452937, Q1363377, 'Folio from an illustrated manuscript'
# Add Q116275431: 468395, Q2413314, 'Jug'
# Add Q116440871: 568595, Q15148, 'Spatula'
# Add Q19920176: 482809, Q3305213, 'Painting'
# Add Q116340387: 8117, Q81895, 'Spoon'
# Add Q116393126: 8991, Q16180001, 'Tumbler'
# Q98821653: AttributeError for object_name: nan
# Add Q78610650: 812305, Q3305213, 'Hanging scroll'
# Add Q19920961: 482484, Q3305213, 'Painting'
# Add Q19925182: 10192, Q3305213, 'Painting, miniature'
# Add Q19923882: 11387, Q18761202, 'Watercolor'
# Add Q100706341: 107677, Q11284623, 'Afternoon dress'
# Add Q116444308: 625908, Q726826, 'Shabti, worker, Nauny'
# Add Q19924497: 15087, Q3305213, 'Painting, miniature'
# Add Q116372445: 1245, Q151771, 'Candlestick'
# Add Q29385498: 470298, Q12791, 'Sword'
# Add Q29385498: 470298, Q661140, 'Sword'
# Add Q116435579: 559723, Q46847, 'Ring'
# Add Q116371027: 2730, Q60310748, 'Cream pot'
# Add Q29385558: 501523, Q1823258, 'Soprano Recorder in B'
# Add Q78841073: 45718, Q3305213, 'Painting'
# Add Q116401263: 231913, Q11285759, 'Armchair'
# Add Q116440157: 567861, Q2442735, 'Scarab'
# Add Q116294202: 241062, Q860861, 'Head of a woman'
# Add Q116445567: 852563, Q11060274, 'Print'
# Add Q116399387: 200922, Q151771, 'Candlestick'
# Add Q116287505: 251561, Q2413314, 'Jug'
# Add Q116252614: 471047, Q12537, 'Corbel'
# Add Q98820708: 264178, Q125191, 'Photograph'
# Add Q29384364: 316442, Q5771190, 'Saltcellar'
# Add Q116246271: 591018, Q726826, 'Shabti, Henettawy C'
# Add Q98225261: 765285, Q3305213, 'Painting'
# Add Q116288761: 256067, Q2111434, 'Pendant'
# Add Q97581410: 302664, Q1757923, 'Carte-de-visite'
# Add Q116358283: 6691, Q3579073, 'Porringer'
# Add Q116248327: 450933, Q153988, 'Bowl'
# Add Q116311401: 190838, Q468402, 'Tile'
# Add Q96807108: 283782, Q125191, 'Photograph'
# Add Q116411389: 472835, Q499916, 'Brooch'
# Add Q19904855: 435668, Q3305213, 'Painting, predella panel'
# Add Q116274720: 562750, Q11086567, 'Relief fragment, tomb of Meketre'
# Add Q96800572: 268348, Q125191, 'Photograph'
# Add Q20201408: 469890, Q3305213, 'Roundel'
# Add Q116289552: 245761, Q673338, 'Alabastron'
# Add Q29385792: 544451, Q1066288, 'Statuette, standing boy, nude, Amenemhab, child'
# Add Q83562224: 39676, Q168456, 'Earring'
# Add Q20199404: 491916, Q3305213, 'Drawing'
# Add Q116409791: 451003, Q1264081, 'Incense burner'
# Add Q116370711: 3096, Q3917316, 'Decanter'
# Add Q116429134: 555254, Q131557, 'Amulet, Heart'
# Add Q96035516: 403906, Q1190417, 'Baseball card, photograph'
# Add Q116296620: 247925, Q579418, 'Lekythos'
# Add Q78808847: 51575, Q3305213, 'Handscroll'
# Add Q20178131: 13263, Q3305213, 'Drawing'
# Add Q116357300: 5869, Q132397, 'Pitcher'
# Add Q116373407: 405, Q833823, 'Beaker'
# Add Q116342384: 8024, Q2356786, 'Sugar Bowl'
# Add Q116344953: 8384, Q245005, 'Teapot'
# Add Q116372060: 1621, Q63495428, 'Side Chair'
# Add Q116432948: 558535, Q2442735, 'Scarab'
# Add Q98821666: 787918, Q125191, 'Photograph'
# Add Q6067946: 544232, Q3373936, 'Necklace, pectoral, Sithathoryunet-view-jewelry, Senwosret II'
# Add Q98821338: 270574, Q125191, 'Photograph'
# Add Q116276475: 468158, Q6806674, 'Pharmacy jar'
# Add Q116445448: 834048, Q722604, 'Reliquary'
# Add Q19924876: 13453, Q3305213, 'Painting'
# Add Q97581411: 302665, Q1757923, 'Carte-de-visite'
# Add Q78849899: 45202, Q3305213, 'Hanging scroll'
# Add Q19924726: 12890, Q3305213, 'Painting
# Frigate Presiden
# Frigate President and
# H.B.M. Endymion'
# WARNING: API error modification-failed: String should not start or end with whitespace nor include vertical whitespace or tabs: Painting Frigate Presiden Frigate President and H.B.M. Endymion
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[60], line 180
#     178 counter.start_time = perf_counter()
#     179 for item in pbar:
# --> 180     handle_item(item)
#     182 # Possible joblib speedup? Not happening
#     183 # Parallel(n_jobs=8, prefer="threads")(delayed(handle_item)(i) for i in generator)
#     184 counter.end_time = perf_counter()
#
# Cell In[60], line 136, in handle_item(item)
#     134         tqdm.write(f"  could not set object name to {object_name}")
#     135         return
# --> 136     statement.addQualifier(qualifier) # summary=u'Adding a qualifier.'
#     138     counter.statements += 1
#     140 counter.supplemented += 1
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/page/_wikibase.py:1837, in Claim.addQualifier(self, qualifier, **kwargs)
#    1834     raise ValueError(
#    1835         'The provided Claim instance is already used in an entity')
#    1836 if self.on_item is not None:
# -> 1837     data = self.on_item.repo.editQualifier(self, qualifier, **kwargs)
#    1838     self.on_item.latest_revision_id = data['pageinfo']['lastrevid']
#    1839     qualifier.on_item = self.on_item
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/site/_decorators.py:92, in need_right.<locals>.decorator.<locals>.callee(self, *args, **kwargs)
#      88 elif right is not None and not self.has_right(right):
#      89     raise UserRightsError('User "{}" does not have required '
#      90                           'user right "{}"'
#      91                           .format(self.user(), right))
# ---> 92 return fn(self, *args, **kwargs)
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/tools/_deprecate.py:479, in remove_last_args.<locals>.decorator.<locals>.wrapper(*__args, **__kw)
#     473     deprecated = [arg for arg in arg_names if arg in deprecated]
#     474     warn("The trailing arguments ('{}') of {} are deprecated. "
#     475          "The value(s) provided for '{}' have been dropped."
#     476          .format("', '".join(arg_names), name,
#     477                  "', '".join(deprecated)),
#     478          DeprecationWarning, depth)
# --> 479 return obj(*new_args, **new_kwargs)
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/site/_datasite.py:502, in DataSite.editQualifier(self, claim, qualifier, new, bot, summary)
#     499 params['property'] = qualifier.getID()
#     501 req = self.simple_request(**params)
# --> 502 return req.submit()
#
# File /srv/paws/lib/python3.10/site-packages/pywikibot/data/api/_requests.py:1094, in Request.submit(self)
#    1090     pywikibot.log('API Error: query=\n{}'
#    1091                   .format(pprint.pformat(param_repr)))
#    1092     pywikibot.log(f'           response=\n{result}')
# -> 1094     raise pywikibot.exceptions.APIError(**error)
#    1095 except TypeError:
#    1096     raise RuntimeError(result)
#
# APIError: modification-failed: String should not start or end with whitespace nor include vertical whitespace or tabs: Painting Frigate Presiden Frigate President and H.B.M. Endymion
# [messages: [{'name': 'wikibase-validator-illegal-string-chars', 'parameters': ['Painting\r\nFrigate Presiden\r\nFrigate President and\r\nH.B.M. Endymion'], 'html': {'*': 'String should not start or end with whitespace nor include vertical whitespace or tabs: Painting\r\nFrigate Presiden\r\nFrigate President and\r\nH.B.M. Endymion'}}];
#  servedby: mw1465;
#  help: See https://www.wikidata.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.]
